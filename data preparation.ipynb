# %%
import os
import requests
import json
from datasets import Dataset, DatasetDict

# %%
# GitHub raw file URLs
base_url = "https://raw.githubusercontent.com/laith85/Transformer_NMT_AD/main/"
data_files = {
    "Gulf": ("Gulf_Dialects.txt", "MSA_For_Gulf_Dialects.txt"),
    "Iraqi": ("Iraqi_Dialects.txt", "MSA_For_Iraqi_Dialects.txt"),
    "Levantine": ("Levantine_Dialects.txt", "MSA_For_Levantine_Dialects.txt"),
    "Nile Basin": ("Nile Basin_ Dialects.txt", "MSA_For_Nile_Basin_Dialects.txt"),
    "North Africa": ("North_Africa _Dialect.txt", "MSA_For_North_Africa_Dialects.txt")
}

# Initialize list to hold each data entry as a dictionary
data_entries = []

# Function to download and read content from GitHub
def fetch_content(file_url):
    response = requests.get(file_url)
    response.raise_for_status()  # Raise error for bad status
    return response.text.splitlines()

# Load data from files in GitHub
for dialect, (dialect_file, msa_file) in data_files.items():
    dialect_url = base_url + dialect_file
    msa_url = base_url + msa_file
    
    dialect_sentences = fetch_content(dialect_url)
    msa_sentences = fetch_content(msa_url)
    
    # Ensure same number of sentences in dialect and MSA files
    assert len(dialect_sentences) == len(msa_sentences), \
        f"Mismatch in lines for {dialect_file} and {msa_file}"
    
    # Combine text, translation, and label into a dictionary for each sentence pair
    for dialect_sentence, msa_sentence in zip(dialect_sentences, msa_sentences):
        data_entries.append({
            "text": dialect_sentence.strip(),
            "translation": msa_sentence.strip(),
            "label": dialect
        })

# Save as JSON file
with open("dataset.json", "w", encoding="utf-8") as json_file:
    json.dump(data_entries, json_file, ensure_ascii=False, indent=4)

print("Data saved to dataset.json")
# Out:
# Data saved to dataset.json

# %%
pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: filelock in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=15.0.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (15.0.1)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (0.3.7)
# Requirement already satisfied: pandas in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (2.1.4)
# Requirement already satisfied: requests>=2.32.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (2.32.2)
# Requirement already satisfied: tqdm>=4.66.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Requirement already satisfied: fsspec<=2024.9.0,>=2023.1.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (3.10.5)
# Collecting huggingface-hub>=0.23.0 (from datasets)
#   Downloading huggingface_hub-0.26.2-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: packaging in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp->datasets) (2.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp->datasets) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp->datasets) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from aiohttp->datasets) (1.9.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from huggingface-hub>=0.23.0->datasets) (4.11.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (1.26.19)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from requests>=2.32.2->datasets) (2024.8.30)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from pandas->datasets) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/envs/Python-RT24.1/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 480.6/480.6 kB 31.7 MB/s eta 0:00:00
# Downloading huggingface_hub-0.26.2-py3-none-any.whl (447 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 447.5/447.5 kB 39.9 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 16.6 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 15.2 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 22.8 MB/s eta 0:00:00
# Installing collected packages: xxhash, dill, multiprocess, huggingface-hub, datasets
#   Attempting uninstall: dill
#     Found existing installation: dill 0.3.7
#     Uninstalling dill-0.3.7:
#       Successfully uninstalled dill-0.3.7
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface-hub 0.20.3
#     Uninstalling huggingface-hub-0.20.3:
#       Successfully uninstalled huggingface-hub-0.20.3
# Successfully installed datasets-3.1.0 dill-0.3.8 huggingface-hub-0.26.2 multiprocess-0.70.16 xxhash-3.5.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import requests
import json
import random
from datasets import Dataset, DatasetDict

# GitHub raw file URLs
base_url = "https://raw.githubusercontent.com/laith85/Transformer_NMT_AD/main/"
data_files = {
    "Gulf": ("Gulf_Dialects.txt", "MSA_For_Gulf_Dialects.txt"),
    "Iraqi": ("Iraqi_Dialects.txt", "MSA_For_Iraqi_Dialects.txt"),
    "Levantine": ("Levantine_Dialects.txt", "MSA_For_Levantine_Dialects.txt"),
    "Nile Basin": ("Nile Basin_ Dialects.txt", "MSA_For_Nile_Basin_Dialects.txt"),
    "North Africa": ("North_Africa _Dialect.txt", "MSA_For_North_Africa_Dialects.txt")
}

# Initialize list to hold each data entry as a dictionary
data_entries = []

# Function to download and read content from GitHub
def fetch_content(file_url):
    response = requests.get(file_url)
    response.raise_for_status()  # Raise error for bad status
    return response.text.splitlines()

# Load data from files in GitHub
for dialect, (dialect_file, msa_file) in data_files.items():
    dialect_url = base_url + dialect_file
    msa_url = base_url + msa_file
    
    dialect_sentences = fetch_content(dialect_url)
    msa_sentences = fetch_content(msa_url)
    
    # Ensure same number of sentences in dialect and MSA files
    assert len(dialect_sentences) == len(msa_sentences), \
        f"Mismatch in lines for {dialect_file} and {msa_file}"
    
    # Combine text, translation, and label into a dictionary for each sentence pair
    for dialect_sentence, msa_sentence in zip(dialect_sentences, msa_sentences):
        data_entries.append({
            "text": dialect_sentence.strip(),
            "translation": msa_sentence.strip(),
            "label": dialect
        })

# Now, take 5% from each category
sampled_entries = []

# Iterate over each dialect and take 5% of the data entries
for dialect in data_files.keys():
    # Filter data for the current dialect
    dialect_data = [entry for entry in data_entries if entry['label'] == dialect]
    
    # Calculate 5% of the dialect data
    sample_size = int(len(dialect_data) * 0.05)
    
    # Randomly select 5% of the data
    sampled_dialect_data = random.sample(dialect_data, sample_size)
    
    # Append the sampled data to the final list
    sampled_entries.extend(sampled_dialect_data)

# Save the sampled data as a new JSON file
with open("sampled_dataset.json", "w", encoding="utf-8") as json_file:
    json.dump(sampled_entries, json_file, ensure_ascii=False, indent=4)

print("Sampled data saved to sampled_dataset.json")
# Out:
# Sampled data saved to sampled_dataset.json

# %%
data_entries
# Out:
# [{'text': 'موجود في نهاية الممر، بجيب لك شوي الحين. اذا احتجت شي ثاني خبرني.',
#   'translation': 'إنها في أخر القاعة . سوف آتي لك ببعض منها الآن . إذا أردت أي شيئاً آخر فقط أعلمني .',
#   'label': 'Gulf'},
#  {'text': 'تسوي تعديلات؟',
#   'translation': 'هل تقومون بعمل تعديلات ؟',
#   'label': 'Gulf'},
#  {'text': 'بغينا طاولة يم الدريشة.',
#   'translation': 'نريد مائدة بجانب النافذة .',
#   'label': 'Gulf'},
#  {'text': 'هو ذاك الصوب، بالضبط جدام استعلامات السياح بالضبط.',
#   'translation': 'هناك ، أمام بيانات السائح تماما .',
#   'label': 'Gulf'},
#  {'text': 'ما قط سمعت بهالعنوان في هالمنطقة من قبل.',
#   'translation': 'لم اسمع بهذا العنوان من قبل بالقرب من هنا .',
#   'label': 'Gulf'},
#  {'text': 'امش سيده لين تشوف صيدلية.',
#   'translation': 'استمر في السير في هذا الطريق حتى تجد صيدلية .',
#   'label': 'Gulf'},
#  {'text': 'شنو اللون اللي هابين فيه هالفترة؟',
#   'translation': 'ما هو أحدث لون هذا الموسم .',
#   'label': 'Gulf'},
#  {'text': 'في حالتي انا دايماً حق شغل، نادراً حق استانس.',
#   'translation': 'في حالتي ، غالباً ما يكون من أجل العمل ونادراً ما يكون للاستمتاع .',
#   'label': 'Gulf'},
#  {'text': 'بقعد يومين.', 'translation': 'سأقيم لمدة يومين .', 'label': 'Gulf'},
#  {'text': 'بغيت كيرلي ضيق.',
#   'translation': 'أريد تمويج متقارب بشعري',
#   'label': 'Gulf'},
#  {'text': 'بغيت احجز غرفتين مزدوجتين.',
#   'translation': 'أريد حجز غرفتين مزدوجتين .',
#   'label': 'Gulf'},
#  {'text': 'ما أبغيه منزوع.',
#   'translation': 'لا أريد إزالتها .',
#   'label': 'Gulf'},
#  {'text': 'يوقف هالباص في شارع ستونر؟',
#   'translation': 'هل هذه الحافلة تتوقف في شارع أستونر ؟',
#   'label': 'Gulf'},
#  {'text': 'افتح حلجك قد ما تقدر.',
#   'translation': 'من فضلك افتح فمك على مداه .',
#   'label': 'Gulf'},
#  {'text': 'بكم الريوق؟', 'translation': 'كم تكلفة الإفطار ؟', 'label': 'Gulf'},
#  {'text': 'شلون اقدر اساعدك؟',
#   'translation': 'كيف أستطيع مساعدتك ؟',
#   'label': 'Gulf'},
#  {'text': 'خل ناخذ شي ناكله.',
#   'translation': 'دعنا نأخذ قطعة لنأكلها .',
#   'label': 'Gulf'},
#  {'text': 'خذ ثالث لفة يسار.',
#   'translation': 'اتجه يسارا عند الناصية الثالثة .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تنظف هالثياب؟',
#   'translation': 'هل لك أن تقوم بتنظيف هذه الملابس ؟',
#   'label': 'Gulf'},
#  {'text': 'عطيتك رقم تلفونه وعنوانه.',
#   'translation': 'أعطيك رقم تليفونه وعنوانه .',
#   'label': 'Gulf'},
#  {'text': 'دفعت مصاريف الوجبات والفندق مقدم.',
#   'translation': 'لقد قمت بتسديد ثمن الوجبات ورسوم الفندق مقدماًً .',
#   'label': 'Gulf'},
#  {'text': 'قاعد ادور مطعم مشويات زين وهادي. ممكن تأشر عليهم في الخريطة؟',
#   'translation': 'أبحث عن مطعم جيد ، للمشويات . هل يمكنك أن تشير إلى أماكن تلك المطاعم على الخريطة ؟',
#   'label': 'Gulf'},
#  {'text': 'اذا كسرته تشتريه.',
#   'translation': 'أنت تقوم بكسرها ، فأنت الذي اشتريتها .',
#   'label': 'Gulf'},
#  {'text': 'بقول لها تكلمك اول ما ترجع.',
#   'translation': 'سوف أخبرها بأن تتصل بك بمجرد أن تصل .',
#   'label': 'Gulf'},
#  {'text': 'بغيت سكر وكريمة في القهوة؟',
#   'translation': 'هل تحب أن تضع قشدة وسكر في قهوتك ؟',
#   'label': 'Gulf'},
#  {'text': 'هي متعورة واجد.',
#   'translation': 'لقد أصيبت إصابة بالغة .',
#   'label': 'Gulf'},
#  {'text': 'بغيت ولاعة.', 'translation': 'أريد قداحة .', 'label': 'Gulf'},
#  {'text': 'في تجهيزات للمؤتمرات في هالفندق؟',
#   'translation': 'هل لدى هذا الفندق تجهيزات للمؤتمرات ؟',
#   'label': 'Gulf'},
#  {'text': 'معليه ناكل وجبة خفيفة؟',
#   'translation': 'هل من المناسب أن نتناول وجبة خفيفة ؟',
#   'label': 'Gulf'},
#  {'text': 'انا اتصل من المطار، بكون عندك على الساعة اربع.',
#   'translation': 'أنا أتصل من المطار . سأصل هناك في حوالي الساعة الرابعة .',
#   'label': 'Gulf'},
#  {'text': 'وين اقدر احول لشيكاغو؟',
#   'translation': 'أين سأغير إلى شيكاغو .',
#   'label': 'Gulf'},
#  {'text': 'كم يكلف ارسال رسالة مسجلة لفرنسا؟',
#   'translation': 'كم تكلفة إرسال خطاب مسجل إلى فرنسا ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن تصرف لي قيمة جيكي بو ميتين دولار كاش؟',
#   'translation': 'هل يمكنكم صرف الشيك ذو المائتي دولار الخاص بي ؟',
#   'label': 'Gulf'},
#  {'text': 'وايد فرق لما تسوق على الجهة اليمين.',
#   'translation': 'إن القيادة على الجانب الأيمن من الطريق مختلفة تماماً بالفعل .',
#   'label': 'Gulf'},
#  {'text': 'الممثل واجد عجيب.',
#   'translation': 'كان الممثل رائعا بالفعل .',
#   'label': 'Gulf'},
#  {'text': 'وين قسم الكتب الواقعية؟',
#   'translation': 'أين الجانب غير الخيالي في شخصيتك ؟',
#   'label': 'Gulf'},
#  {'text': 'اذا المفروض يصير، اتصل فيني.',
#   'translation': 'إذا حدث ذلك ، من فضلك أتصل بي .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تغير كرسيي؟',
#   'translation': 'هل يمكن أن تغير مقعدي من فضلك ؟',
#   'label': 'Gulf'},
#  {'text': 'في ضمان؟', 'translation': 'هل هناك ضمانا ؟', 'label': 'Gulf'},
#  {'text': 'مسامحة، بحط بالي على الكلب.',
#   'translation': 'عفوا , أنا سأعتني بالكلب .',
#   'label': 'Gulf'},
#  {'text': 'بغيت تذكرتين حق "كاتس" هالخميس.',
#   'translation': 'أريد تذكرتين للقطط ليوم الخميس .',
#   'label': 'Gulf'},
#  {'text': 'وين الكوفي شوب؟', 'translation': 'أين المقهى ؟', 'label': 'Gulf'},
#  {'text': 'بغيت فانلة يهال.',
#   'translation': 'أريد جاكيت للأطفال .',
#   'label': 'Gulf'},
#  {'text': 'شسمك مرة ثانية؟',
#   'translation': 'اسمك مرة ثانية ؟',
#   'label': 'Gulf'},
#  {'text': 'سيد براون موجود؟',
#   'translation': 'هل مستر برون هناك ؟',
#   'label': 'Gulf'},
#  {'text': 'اوكي. يكلف خمسة وثمانين سنت بالبريد العادي وثلاث دولارات بالضبط زيادة حق التسليم الخاص.',
#   'translation': 'حسنا . إنها تتكلف خمسة وثمانون دولارا في البريد العادي وثلاثة دولارات في التوصيل الخاص .',
#   'label': 'Gulf'},
#  {'text': 'ممكن أأجر طراد حق يوم واحد؟',
#   'translation': 'هل يمكن أن أؤجر قارب ليوم ؟',
#   'label': 'Gulf'},
#  {'text': 'في أي كشك يصير احجز؟',
#   'translation': 'عند أي نافذة يمكن أن أقوم بعمل الحجز ؟',
#   'label': 'Gulf'},
#  {'text': 'شنو ذي؟', 'translation': 'ما هذا ؟', 'label': 'Gulf'},
#  {'text': 'ممكن تقول لي شلون اروح الأوبرا؟',
#   'translation': 'هل يمكنك أن تخبريني كيف أستطيع أن أصل إلى الأوبرا ؟',
#   'label': 'Gulf'},
#  {'text': 'حبيبي مو جنك كنت واجد سكران البارحة؟',
#   'translation': 'ألم تكن مخمور بدرجة كبيرة بعض الشيء في الليلة الماضية يا عزيزي ؟',
#   'label': 'Gulf'},
#  {'text': 'اتبع تعليمات موظفينا لو سمحت.',
#   'translation': 'من فضلك اتبع التعليمات الصادرة من موظفينا .',
#   'label': 'Gulf'},
#  {'text': 'في مركز تجاري قريب من هني؟',
#   'translation': 'هل يوجد هنا محل متعدد الأقسام بالقرب من هنا .',
#   'label': 'Gulf'},
#  {'text': 'فل، لو سمحت.',
#   'translation': 'املأ خزان الوقود من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'في غرفة أرخص؟',
#   'translation': 'هل يوجد غرفة بسعر أرخص ؟',
#   'label': 'Gulf'},
#  {'text': 'افضل سيارة اوتوماتيك.',
#   'translation': 'أفضل سيارة بها نظام إلي لنقل الحركة .',
#   'label': 'Gulf'},
#  {'text': 'بسكن في سكن جامعة هارفارد.',
#   'translation': 'سأقيم في مسكن الطلبة الخاص بجامعة هارفارد .',
#   'label': 'Gulf'},
#  {'text': 'شنو السعر اليوم؟',
#   'translation': 'ما هو سعر الصرف اليوم ؟',
#   'label': 'Gulf'},
#  {'text': 'فيني ربو مزمن.',
#   'translation': 'أعاني بشكل مزمن من الربو .',
#   'label': 'Gulf'},
#  {'text': 'عندي ثلاثة آلاف دولار تقريباً.',
#   'translation': 'معي حوالي ثلاثة آلاف دولاراً .',
#   'label': 'Gulf'},
#  {'text': 'اوكي. الطبق ايي مع بطاطس او أرز بيلاف. شنو تفضل؟',
#   'translation': 'حسناً ، سيدي . فقد أتت بخيارين مقليات فرنسية أو أرز بالتوابل واللحم ، أيهما تحب ؟',
#   'label': 'Gulf'},
#  {'text': 'شلون اروح هالمكان؟',
#   'translation': 'كيف أصل إلى ذلك المكان ؟',
#   'label': 'Gulf'},
#  {'text': 'شنوع القصة؟',
#   'translation': 'أي نوع من القصص هي ؟',
#   'label': 'Gulf'},
#  {'text': 'ثلاث مرات.', 'translation': 'ثلاث مرات .', 'label': 'Gulf'},
#  {'text': 'اي كشك يبيع طوابع؟',
#   'translation': 'أي نافذة تبيع الطوابع ؟',
#   'label': 'Gulf'},
#  {'text': 'هاجمني وعقب راح في فان ابيض.',
#   'translation': 'بعد أن هاجمني ، هرب في شاحنة بيضاء .',
#   'label': 'Gulf'},
#  {'text': 'اوكي. لو سمحت خل هالبطاقة عندك وطلعها لما تجي تستلمه.',
#   'translation': 'حسنا . من فضلك احتفظ بهذه القسيمة وقدمها عندما تقوم بالاختيار .',
#   'label': 'Gulf'},
#  {'text': 'لو كنت مكانك جان بشتري هذي.',
#   'translation': 'كنت سأشتري هذا إن كنت في مكانك ؟',
#   'label': 'Gulf'},
#  {'text': 'ميتين دولار. كاش او كردت كارد؟',
#   'translation': 'مائتي دولار . فوري أم عبر البطاقات الائتمانية .',
#   'label': 'Gulf'},
#  {'text': 'شكثر تاخذ مدة الرحلة على هالبركة؟',
#   'translation': 'كم من الوقت تستغرق السفينة لعبور هذا المحيط ؟',
#   'label': 'Gulf'},
#  {'text': 'في اكل لازم اتجنبه وانا اخذ هالدوا؟',
#   'translation': 'هل علىّ أن أتجنب أنواع معينة من الطعام خلال فترة تناولي هذا الدواء ؟',
#   'label': 'Gulf'},
#  {'text': 'بتكون في اي صعوبات مع الجمارك؟',
#   'translation': 'هل لديك أحذية حريمي عند أصابع القدم ؟',
#   'label': 'Gulf'},
#  {'text': 'عندك جواتي رسمية حق الرجول العريضة؟',
#   'translation': 'هل ستواجهني أية صعوبات في الجمارك ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت واين احمر؟',
#   'translation': 'هل لي ببعض النبيذ الأحمر ؟',
#   'label': 'Gulf'},
#  {'text': 'خبرني لين وصلنا المتحف.',
#   'translation': 'أخبرني عندما نصل إلى المتحف .',
#   'label': 'Gulf'},
#  {'text': 'يروح هالباص لفندق الشيراتون؟',
#   'translation': 'هل يذهب هذا الأتوبيس إلى فندق الشيراتون .',
#   'label': 'Gulf'},
#  {'text': 'كم يصير؟',
#   'translation': 'إلى أي شيء وصل ذلك الأمر ؟',
#   'label': 'Gulf'},
#  {'text': 'شوي حر. عادي ابطل الدريشة؟',
#   'translation': 'إنه ساخن بدرجة بسيطة . هل يمكن أن أفتح النافذة ؟',
#   'label': 'Gulf'},
#  {'text': 'بس شور اوكي.', 'translation': 'فقط دش يكفي .', 'label': 'Gulf'},
#  {'text': 'عيوني حمر.', 'translation': 'عيني محمرة قليلا .', 'label': 'Gulf'},
#  {'text': 'لا. بغيت غرفة مزدوجة بس حق استخدام فردي؟ عندنا وحدة.',
#   'translation': 'لا ، هل لي أن أقترح أخذ غرفة ذات سريرين للاستخدام الفردي ؟ فنحن لدينا واحدة .',
#   'label': 'Gulf'},
#  {'text': 'ماقدر اضمن لك، بس بنحاول.',
#   'translation': 'لا أستطيع تأكيد ذلك لكنا سنبذل قصارى جهدنا .',
#   'label': 'Gulf'},
#  {'text': 'ابغي كيرلي ضيق، لو سمحت.',
#   'translation': 'أريد تمويج متقارب لشعري ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'تقدر تشوف البحر تحت من بعيد.',
#   'translation': 'كان البحر إلى الأسفل من بعيد .',
#   'label': 'Gulf'},
#  {'text': 'هي تبغي بير.', 'translation': 'هي تريد بيرة .', 'label': 'Gulf'},
#  {'text': 'تحتاج عملية.',
#   'translation': 'أنت بحاجة إلى إجراء عملية .',
#   'label': 'Gulf'},
#  {'text': 'بيض اكثر، لو سمحت.',
#   'translation': 'المزيد من البيض من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'وين محطة الباص حق سنترال بارك؟',
#   'translation': 'أين محطة الأتوبيس المتجه إلى سنترال بارك ؟',
#   'label': 'Gulf'},
#  {'text': 'تكاسي؟', 'translation': 'سيارة أجرة ؟', 'label': 'Gulf'},
#  {'text': 'تفضل مفتاحك اخوي. غرفة خمسة آلاف وستمية واثنعش.',
#   'translation': 'ها هو مفتاحك ، يا سيدي . غرفة ستة وخمسون إثنى عشر .',
#   'label': 'Gulf'},
#  {'text': 'عجبني قميصك.',
#   'translation': 'أحب الجاكت الخاص بك .',
#   'label': 'Gulf'},
#  {'text': 'تفضل.', 'translation': 'استمر .', 'label': 'Gulf'},
#  {'text': 'وصلنا. هذي فندقك.',
#   'translation': 'ها نحن قد وصلنا هذا هو فندقك .',
#   'label': 'Gulf'},
#  {'text': 'متى تبتدي مباراة كرة السلة؟',
#   'translation': 'متى بدأت مباراة كرة السلة ؟',
#   'label': 'Gulf'},
#  {'text': 'صباح الخير. شلونك؟',
#   'translation': 'صباح الخير . كيف حالك .',
#   'label': 'Gulf'},
#  {'text': 'مسامحة بس لازم اشوف شي يثبت الهوية.',
#   'translation': 'أسف أنني بحاجة إلى أن أطلع على أي مستند لتحديد الهوية .',
#   'label': 'Gulf'},
#  {'text': 'شرايك؟', 'translation': 'ماذا كان انطباعك ؟', 'label': 'Gulf'},
#  {'text': 'أكيد. بغيت قهوتك مع العشا او بعده؟',
#   'translation': 'بالتأكيد . هل ترغب في تناول القهوة مع العشاء أم بعد ذلك ؟',
#   'label': 'Gulf'},
#  {'text': 'بسافر على طيارة اثنعش لي طوكيو.',
#   'translation': 'إنني سأستقل الرحلة الجوية رقم اثنى عشر المتجهة إلى طوكيو .',
#   'label': 'Gulf'},
#  {'text': 'بغيت اسوي مكالمة خارجية، لو سمحت.',
#   'translation': 'أود إجراء مكالمة دولية ، من فضلك ؟',
#   'label': 'Gulf'},
#  {'text': 'خمس شهور.', 'translation': 'خمسة أشهر .', 'label': 'Gulf'},
#  {'text': 'في اي ايام من الاسبوع يصير؟',
#   'translation': 'في أي أيام الأسبوع تتم ؟',
#   'label': 'Gulf'},
#  {'text': 'اي نوع صوص؟',
#   'translation': 'أي نوع من الملابس ؟',
#   'label': 'Gulf'},
#  {'text': 'هذي بارد شوي، ممكن تسخنه؟',
#   'translation': 'هذا بارد إلى حد ما . هل يمكن أن تقوم بتسخينه ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت جل شعر.',
#   'translation': 'أريد بعض الجل المصفف للشعر .',
#   'label': 'Gulf'},
#  {'text': 'مسامحة هالمكان مأخوذ.',
#   'translation': 'أسف ، هذا المكان محجوز بالفعل .',
#   'label': 'Gulf'},
#  {'text': 'ممكن نشوف منيو؟',
#   'translation': 'هل لنا أن نطلع على القائمة ؟',
#   'label': 'Gulf'},
#  {'text': 'مقاسي ستة.', 'translation': 'مقاسي ستة .', 'label': 'Gulf'},
#  {'text': 'انا بخير. بس يصير تكلم رفيجي؟',
#   'translation': 'أنا بحالة جدية ، لكن هل تمانع في الاتصال بصديق ؟',
#   'label': 'Gulf'},
#  {'text': 'شكراً، هذي يكفي.',
#   'translation': 'شكراً ، هذا يكفي .',
#   'label': 'Gulf'},
#  {'text': 'ما بيوقف لك أي تكسي الا اذا وقفت عند محطة التكاسي.',
#   'translation': 'لن يقف أية سيارة أجرة ما لم تنتظر في موقف السيارات ؟',
#   'label': 'Gulf'},
#  {'text': 'ميزانيتي اقل من خمسين دولار حق الليلة.',
#   'translation': 'ميزانيتي لا تتجاوز الخمسون دولاراً في الليلة .',
#   'label': 'Gulf'},
#  {'text': 'يصير تصور معاي؟',
#   'translation': 'هل سنأخذ صورة معا ؟',
#   'label': 'Gulf'},
#  {'text': 'كم رسوم الخدمة؟',
#   'translation': 'كم تبلغ رسوم هذه الخدمة ؟',
#   'label': 'Gulf'},
#  {'text': 'المبيعات الكلية في امريكا الشمالية ارتفعت أكثر من خمسة بالمية؟',
#   'translation': 'هل ارتفع إجمالي المبيعات في أمريكا الشمالية بما يزيد عن خمسة بالمائة ؟',
#   'label': 'Gulf'},
#  {'text': 'من احسن صديق عندك؟',
#   'translation': 'من هو أفضل صديق لك ؟',
#   'label': 'Gulf'},
#  {'text': 'انت تدري ان واحد من اكبر ابطال السومو، اللي هي نوع من انواع المصارعات التقليدية بشكل ياباني، اصله امريكي؟',
#   'translation': 'هل تعلم أن أحد أكبر بطولات السومو ، نوع من المصارعة اليابانية التقليدية ، بطولة أمريكية ؟',
#   'label': 'Gulf'},
#  {'text': 'يوم الصحة والرياضة تاريخ عشرة اكتوبر هو عطلة وطنية مسوينها عشان يشجعون صحة الناس.',
#   'translation': 'يوم الصحة الرياضية هو يوم العاشر من أكتوبر وهو إجازة قومية الغرض منها تحسين صحة المواطنين .',
#   'label': 'Gulf'},
#  {'text': 'هذي حق وول ستريت؟',
#   'translation': 'هل هذا خاص بوول ستريت ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت أأجره من خمسة لي عشرة ديسمبر.',
#   'translation': 'أرغب في تأجير هذه من الخامس حتى العاشر من ديسمبر .',
#   'label': 'Gulf'},
#  {'text': 'اوكي. وانتي، يا اختي؟',
#   'translation': 'بحالة جيدة ، وكيف حالك أنت ، يا سيدتي ؟',
#   'label': 'Gulf'},
#  {'text': 'تبغيني اجيك تحت البانيت؟',
#   'translation': 'هل تريد أن افحص موتور السيارة ؟',
#   'label': 'Gulf'},
#  {'text': 'سكر؟', 'translation': 'سكر ؟', 'label': 'Gulf'},
#  {'text': 'يصير ادفع بماستر كارد؟',
#   'translation': 'هل يمكنني أن ادفع عن طريق الماستر كارد ؟',
#   'label': 'Gulf'},
#  {'text': 'من هني نستلم الشناط من رحلة ان دبليو تسعمية وسبعة؟',
#   'translation': 'هل هذا هو المكان المخصص لجمع الحقائب الخاصة برحلة ان دبليو رقم تسعة صفر سبعة ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت هالماركة.',
#   'translation': 'سآخذ هذا النوع .',
#   'label': 'Gulf'},
#  {'text': 'وايد مستانس اني قدرت ايي هالدولة.',
#   'translation': 'إنني سعيد جداً لأنني تمكنت من المجيء إلى هذا البلد .',
#   'label': 'Gulf'},
#  {'text': 'اسمي وعنواني عليه.',
#   'translation': 'اسمي وعنواني موجودين عليها .',
#   'label': 'Gulf'},
#  {'text': 'تقدر تساعدني ادور شنطتي؟',
#   'translation': 'هل لك أن تساعدني في الوصول إلى حقيبتي ؟',
#   'label': 'Gulf'},
#  {'text': 'شنو نوع هالحجر؟',
#   'translation': 'أي نوع من الأحجار هذه ؟',
#   'label': 'Gulf'},
#  {'text': 'ابغي اوضح ان حكومتنا ما تعامل اللي يسمونهم ناس القوارب بشكل زين. لاحظت ان اليابان اصلاً كثافتها السكانية مرتفعة واجد فما تقدر تدخل هالضيوف اللي محد عزمهم. بس، من ناحية ثانية، واجد قطاعات صناعية عندنا تحتاج موارد عمال يدوية.',
#   'translation': 'أود أن أشير إلى أن حكومتنا تتعامل بشدة مع من يطلق عليهم أناس المراكب . لقد أدركت أن اليابان بالفعل به زيادة سكانية بالدرجة التي لا تسمح باستضافة هؤلاء الضيوف غير المدعوين . لكن ومن ناحية أخرى ، فإن العديد من القطاعات الصناعية لدينا بحاجة إلى يد عاملة .',
#   'label': 'Gulf'},
#  {'text': 'تقدر تشوف المدينة كاملة من ذاك الجبل. وايد انواع من الورود تتفتح في هالموسم. وايد حلوين.',
#   'translation': 'من هذا الجبل ، تستطيع رؤية المدينة بأكملها . خلال هذا الموسم العديد من أنواع الزهور تزدهرـ إنها تبدو جميلة جداً .',
#   'label': 'Gulf'},
#  {'text': 'الحقني.', 'translation': 'اتبعني .', 'label': 'Gulf'},
#  {'text': 'قول له ان يامادا اتصل لو سمحت.',
#   'translation': 'من فضلك أخبريه أنت يامادا قد اتصل .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تسوي الترتيبات من قبل؟',
#   'translation': 'هل ستقوم بعمل الترتيبات مقدماً ؟',
#   'label': 'Gulf'},
#  {'text': 'انزين ممكن تملي المعلومات هني؟ بس شنطة وحدة؟',
#   'translation': 'حسنا ، من فضلك ضع هذه البيانات هنا . هل كانت حقيبة واحدة ؟',
#   'label': 'Gulf'},
#  {'text': 'شنو تحب؟ لحم او دجاج او سمج؟',
#   'translation': 'هل ترغب في تناول لحم بقري ، دجاج ، أم أسماك ؟',
#   'label': 'Gulf'},
#  {'text': 'يصير نروح من طريق مختلف في الروحة والردة؟',
#   'translation': 'هل من الممكن أن تأخذ طرق مختلفة للذهاب والعودة .',
#   'label': 'Gulf'},
#  {'text': 'في سناك بار هني؟',
#   'translation': 'هل يوجد مطعم للوجبات الخفيفة هنا ؟',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت، اخوي. ابغي اتسيح في بوسطن.',
#   'translation': 'عذراً يا سيدي . أود استطلاع بعض الأماكن السياحية الموجودة في بوسطن .',
#   'label': 'Gulf'},
#  {'text': 'عندكم منيو بالياباني؟',
#   'translation': 'هل لديك قائمة باللغة اليابانية .',
#   'label': 'Gulf'},
#  {'text': 'وحدة وخمس.',
#   'translation': 'إنها الواحدة وخمس دقائق .',
#   'label': 'Gulf'},
#  {'text': 'قاعد احصل مساعدة. شكراً.',
#   'translation': 'تقدم إلىّ المساعدة ، شكراً لك .',
#   'label': 'Gulf'},
#  {'text': 'بغيت مسكن ألم.',
#   'translation': 'أريد مسكن للألم .',
#   'label': 'Gulf'},
#  {'text': 'من احسن ممثلة عندك؟',
#   'translation': 'من هي الممثلة المفضلة لديك .',
#   'label': 'Gulf'},
#  {'text': 'بغيت واحد بيضاوي.',
#   'translation': 'أريد واحدة بيضاوية الشكل ؟',
#   'label': 'Gulf'},
#  {'text': 'أي نوع من الموسيقى يشغلون هناك؟',
#   'translation': 'ما نوع الموسيقى التي يعزفونها هناك ؟',
#   'label': 'Gulf'},
#  {'text': 'ما عجبني اللون. ورني واحد غير لو سمحت.',
#   'translation': 'لا أحب هذا اللون ، من فضلك أرني لوناً آخر .',
#   'label': 'Gulf'},
#  {'text': 'ودني سوق الصبح لو سمحت.',
#   'translation': 'من فضلك خذني إلى السوق الصباحية .',
#   'label': 'Gulf'},
#  {'text': 'فريم نظارتي مكسور.',
#   'translation': 'الإطار الخاص بنظارتي قد كسر .',
#   'label': 'Gulf'},
#  {'text': 'من الساعة ثلاث.',
#   'translation': 'من الساعة الثالثة .',
#   'label': 'Gulf'},
#  {'text': 'واجد زين. عندي كرسي يم الدريشة. اذا بغيتي تبدلين الكراسي بعدين، يا اختي.',
#   'translation': 'عظيم . لدي مقعد بجوار النافذة . آه ، إذا كنت ترغبين في تبادل المقاعد بعد ذلك , يا آنسة .',
#   'label': 'Gulf'},
#  {'text': 'استانست بالسياحة في نيويورك امس.',
#   'translation': 'لقد استمتعت بجولة الاستطلاع للأماكن السياحية في نيويورك بالأمس .',
#   'label': 'Gulf'},
#  {'text': 'عجبتني الشنطة الزرقه المعروضة في الواجهة.',
#   'translation': 'أنا معجب بالحقيبة الزرقاء الموجودة في شباك العرض .',
#   'label': 'Gulf'},
#  {'text': 'اتصل بالمالك اذا عندك اي مشكلة.',
#   'translation': 'اتصل بصاحب المبنى إذا واجهتك أية مشكلة .',
#   'label': 'Gulf'},
#  {'text': 'غسله ومشطه مثل ماهو الحين، لو سمحت.',
#   'translation': 'اغسله بالشامبو وقم بتصفيفه كم هو الآن , من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'لما توصل، اسأل احد ثاني لو سمحت.',
#   'translation': 'عندما تصل هناك أسأل شخص آخر ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'قول لي اسرع طريقة حق اروح سان فرانسسكو.',
#   'translation': 'من فضلك أخبرني بأسرع طريقة للوصول إلى سان فرنسيسكو .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تعطيني مفتاح غرفة ميتين وخمسطعش؟',
#   'translation': 'هل أستطيع الحصول على مفتاح الحجرة رقم اثنان خمس عشرة ؟',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت، ممكن تصورني؟',
#   'translation': 'معذرة ، هل يمكنك أن تلتقط صوراً لي ؟',
#   'label': 'Gulf'},
#  {'text': 'بس اكتب رقم غرفتك ووقع هني.',
#   'translation': 'فقط أكتب رقم غرفة ووقع هنا .',
#   'label': 'Gulf'},
#  {'text': 'اللون زين بس القياس غلط. تقدر تغيره في ساعة؟',
#   'translation': 'اللون مقبول ، لكن المقاس غير صحيح . هل من الممكن أن تقوم بتغيرها في خلال ساعة ؟',
#   'label': 'Gulf'},
#  {'text': 'بنكون ننتظرك في ذاك اليوم.',
#   'translation': 'سنكون في انتظارك في ذلك اليوم .',
#   'label': 'Gulf'},
#  {'text': 'عندنا اللي يكفينا يومين.',
#   'translation': 'لدينا ما يكفينا للاستمرار لمدة يومين .',
#   'label': 'Gulf'},
#  {'text': 'ما فهمت هذي.',
#   'translation': 'لا أستطيع أن أفهم ذلك .',
#   'label': 'Gulf'},
#  {'text': 'شلون ارجع وجهتي؟',
#   'translation': 'كيف أستطيع أن أرجع مرة أخرى إلى وجهتي والمكان المقصود ؟',
#   'label': 'Gulf'},
#  {'text': 'هذي معفي من الضرايب؟',
#   'translation': 'هل هذا معفى من الضرائب ؟',
#   'label': 'Gulf'},
#  {'text': 'لازم يلعبون اشواط اضافية لين ما احد فيهم ينهي التعادل.',
#   'translation': 'حسناً . إن عليهم أن يقوموا بلعب أدوار إضافية حتى يتم إنهاء حالة التعادل .',
#   'label': 'Gulf'},
#  {'text': 'بغيت تحويلة اربعة وعشرين لو سمحت.',
#   'translation': 'أريد الامتداد أربع وعشرون ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'تقدر تتهجاه؟',
#   'translation': 'هل يمكنك أن تتهجها ؟',
#   'label': 'Gulf'},
#  {'text': 'هاك دولارين. خل الباقي.',
#   'translation': 'تفضل هذان دولاران . احتفظ بالباقي .',
#   'label': 'Gulf'},
#  {'text': 'متى العشا؟', 'translation': 'متى الغداء ؟', 'label': 'Gulf'},
#  {'text': 'مسامحة بس هذا واجد علي.',
#   'translation': 'أسف هذا كثير بالنسبة لي ؟',
#   'label': 'Gulf'},
#  {'text': 'وين انزل حق اروح يونيون سكوير؟',
#   'translation': 'من أين أبدأ كي أصل إلى ميدان ينيون ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن تسأل عند كشك تأجير الألواح اللي هناك.',
#   'translation': 'يمكن أن تستفسر من مكتب التأجير الموجود هناك .',
#   'label': 'Gulf'},
#  {'text': 'هلا جين. ممكن تاخذين هذيلين للتنظيف؟',
#   'translation': 'هيه ، جاين . هل يمكنكما أخذ كل الأشياء إلى عمال النظافة ؟',
#   'label': 'Gulf'},
#  {'text': 'انا في اجازة.', 'translation': 'أنا في إجازة .', 'label': 'Gulf'},
#  {'text': 'لا. انا قايل بزور باريس وانا راجع الديرة.',
#   'translation': 'لا . أنا أخطط لزيارة باريس في طريق عودتي إلى وطني .',
#   'label': 'Gulf'},
#  {'text': 'بتاخذه معاك او تبينا نطرشه؟',
#   'translation': 'هل ستأخذها معك أم سيكون علينا أن نرسلها ؟',
#   'label': 'Gulf'},
#  {'text': 'في آخر الأيام زادوا خبراء الأكل بشكل كبير، صح؟',
#   'translation': 'حدث مؤخراً انتشار في خبراء الطعام ، أليس كذلك ؟',
#   'label': 'Gulf'},
#  {'text': 'صارت ست ساعات الحين تقريباً.',
#   'translation': 'قد حدثت منذ حوالي ست ساعات من الآن .',
#   'label': 'Gulf'},
#  {'text': 'طيارة دلتا واحد واحد اثنين. الإقلاع بيتأخر.',
#   'translation': 'رحلة الخطوط الجوية دلتا رقم واحد واحد اثنان . تم تأخير موعد الركوب .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تعطيني غرفة لشخصين حق الليلة؟',
#   'translation': 'هل يمكنك أن تعطني اثنين لليلة ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن تكتب بيان عن البوقة حق شركتي للتأمين؟',
#   'translation': 'هل يمكن أن تكتب لي بلاغ عن سرقة شركة التأمين الخاصة بي ، من فضلك ؟',
#   'label': 'Gulf'},
#  {'text': 'انا ضعيف في التصوير. أحس الكيمرات البسيطة أحسن لي.',
#   'translation': 'بما أنني غير ماهر باستخدام الكاميرا . فأنا أعتقد أن كاميرا سهلة الاستعمال ربما تكون الأفضل لي .',
#   'label': 'Gulf'},
#  {'text': 'هذي الرصيف حق نيويورك؟',
#   'translation': 'هل هذا هو الرصيف الصحيح لنيويورك .',
#   'label': 'Gulf'},
#  {'text': 'استانس في اجازتك.',
#   'translation': 'استمتع بإجازتك .',
#   'label': 'Gulf'},
#  {'text': 'عطني شاش لو سمحت.',
#   'translation': 'من فضلك أعطني بعض الشاش .',
#   'label': 'Gulf'},
#  {'text': 'بغيت بطاطس مخبوزة مع كريمة حامضة لو سمحت.',
#   'translation': 'أريد بطاطس مشوية وعليها قشدة حامضة الطعم ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'اي، كل عشر دقايق.',
#   'translation': 'نعم ، كل عشر دقائق .',
#   'label': 'Gulf'},
#  {'text': 'واحد هامبرقر وواحد تشيز برقر لو سمحت.',
#   'translation': 'واحد هامبرجر وواحد شيز برجر ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'كم تاخد للاجراءات؟',
#   'translation': 'كم تتقاضى لتطبيع صور الفيلم ؟',
#   'label': 'Gulf'},
#  {'text': 'كل واحد بيدفع حق وجبته.',
#   'translation': 'كلا منا يريد أن يحاسب على وجبته .',
#   'label': 'Gulf'},
#  {'text': 'بسوي جيك آوت بكرة الصبح.',
#   'translation': 'سأدفع الفاتورة صباح غد .',
#   'label': 'Gulf'},
#  {'text': 'انا بعد بروح هناك. شرايك ناخذ تكسي مع بعض؟',
#   'translation': 'إني ذاهب إلى هناك ، أيضا . ما رأيك أن نأخذ سيارة أجرة معاً ؟',
#   'label': 'Gulf'},
#  {'text': 'ايلس البيت بيتك. شتبي تشرب؟ قهوة او شاهي او بارد؟',
#   'translation': 'تفضل كرسي وخذ راحتك . هل أتي لك بشيء لتشربه ؟ قهوة ، شاي أم صودا ؟',
#   'label': 'Gulf'},
#  {'text': 'تسلم، هذا من طيب اصلك.',
#   'translation': 'أنه شيء رائع منك أن تقول ذلك .',
#   'label': 'Gulf'},
#  {'text': 'الموقع كان على كرسي في اللوبي.',
#   'translation': 'المكان كان على كرسي في البهو .',
#   'label': 'Gulf'},
#  {'text': 'لحم مشوي لو سمحت.',
#   'translation': 'لحم بقري مشوي ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'متى بتفضا لنا طاولة؟',
#   'translation': 'ستكون المائدة جاهزة ؟',
#   'label': 'Gulf'},
#  {'text': 'يصير اغير طلبي؟ بغيت خوفعه بدال الحويت.',
#   'translation': 'هل لازال متاح لي أن أغير طلبي ؟ أفضل سمك موسى بدلا من محار الصخر .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تحول الين لي جنيه.',
#   'translation': 'من فضلك غير هذه الينات إلى جنيهات .',
#   'label': 'Gulf'},
#  {'text': 'شنو استئصال الزائدة الدودية؟',
#   'translation': 'يالها من عملية لاستئصال الزائدة الدودية ؟',
#   'label': 'Gulf'},
#  {'text': 'بتعطيني الفاتورة مع تفاصيل العلاج؟',
#   'translation': 'هل سوف تعطيني الفواتير بالتفاصيل عن العلاج الطبي ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت معجم بحجم الجيب لو سمحت.',
#   'translation': 'أريد قاموس جيب ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'والله مادري.',
#   'translation': 'حسناً ، أنا لا أعلم .',
#   'label': 'Gulf'},
#  {'text': 'بالبركة، دريت ان سووك نائب رئيس.',
#   'translation': 'مبروك ، علمت أنه قد تم ترقيتك إلى نائب رئيس .',
#   'label': 'Gulf'},
#  {'text': 'بعد بكرة في الليل.',
#   'translation': 'مساء بعد غد .',
#   'label': 'Gulf'},
#  {'text': 'اعيش في جنوب اليابان.',
#   'translation': 'أنا أعيش في جنوب اليابان .',
#   'label': 'Gulf'},
#  {'text': 'تذكرة روحة وردة حق شيكاغو، لو سمحت.',
#   'translation': 'تذكرة ذهاب وعودة إلى شيكاغو ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'تبغي لحم مقدد او لحم خنزير مع البيض؟',
#   'translation': 'هل تحب أن تتناول مع البيض لحم خنزير مملح أو لحم من فخذ الخنزير ؟',
#   'label': 'Gulf'},
#  {'text': 'حق دراسة.', 'translation': 'للدراسة .', 'label': 'Gulf'},
#  {'text': 'بسرعة لو سمحت.',
#   'translation': 'من فضلك ، أسرع .',
#   'label': 'Gulf'},
#  {'text': 'حق شخصين الساعة سبع. باسم واتانابي.',
#   'translation': 'لشخصين عند الساعة السابعة , الاسم وتاناب .',
#   'label': 'Gulf'},
#  {'text': 'الكنديشن ما يشتغل.',
#   'translation': 'التكييف لا يعمل .',
#   'label': 'Gulf'},
#  {'text': 'الحال جذي كل اثنين.',
#   'translation': 'أنها هكذا كل يوم اثنين .',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت روح لوبي الاقلاع الدولي. بالسلامة.',
#   'translation': 'من فضلك اذهب على قاعة المغادرة الدولية , أتمنى لك رحلة سعيدة .',
#   'label': 'Gulf'},
#  {'text': 'عندكم جولات لباريس على اليوروستار؟',
#   'translation': 'هل لديك أية رحلات إلى باريس عبر قطار يوروستار ؟',
#   'label': 'Gulf'},
#  {'text': 'ساعتي. كانت ديجيتال سيكو.',
#   'translation': 'ساعتي . كانت ساعة سيكو رقمية .',
#   'label': 'Gulf'},
#  {'text': 'يبت شهادة الطب مالتي من اليابان.',
#   'translation': 'لقد أحضرت الشهادة الطبية لطبيبي من اليابان .',
#   'label': 'Gulf'},
#  {'text': 'يسعدنا نقدم لك شراب من اختيارك، وبعده العشا. في دليل كامل عن المشروبات اللي نوفرها في هالرحلة موجود في دليل المعلومات بمجلتنا.',
#   'translation': 'يسعدنا أن نقدم لك الشراب الذي تريده متبوعاً بالغداء . دليل كامل بالمشروبات التي نقدمها على رحلتنا موجودة في دليل المعلومات الخاص بمجلتنا .',
#   'label': 'Gulf'},
#  {'text': 'انت تسكن قريب من هني؟',
#   'translation': 'هل تعيش بالقرب من هنا ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن ترسله لليابان؟',
#   'translation': 'هل يمكنك أن ترسلها إلى اليابان ؟',
#   'label': 'Gulf'},
#  {'text': 'وين محل الهدايا؟',
#   'translation': 'أين محل الهدايا ؟',
#   'label': 'Gulf'},
#  {'text': 'يصير اجيب لك جواب يوم الجمعة؟',
#   'translation': 'هل يمكن أن أرد عليك يوم الجمعة ؟',
#   'label': 'Gulf'},
#  {'text': 'خلني اجيك المفقودات. شنوع الكاميرا؟',
#   'translation': 'حسنا , دعني أتثبت من المفقود والموجود . أي نوع من الكاميرات هي ؟',
#   'label': 'Gulf'},
#  {'text': 'انا جداً آسف، قاعدين نجهز الغرفة اللي بغيتها.',
#   'translation': 'أنا أسف جدا ، نحن نجهز لك الغرفة التي طلبتها .',
#   'label': 'Gulf'},
#  {'text': 'اوه فيها محطات القطار والباصات. عادي احتفظ فيها؟',
#   'translation': 'أوه , أنها تظهر محطات مترو الأنفاق ومحطات الحافلات , هل لي أن أحتفظ بها ؟',
#   'label': 'Gulf'},
#  {'text': 'آآخ، وحشني شيبازوكي.',
#   'translation': 'آه لقد فقدت شبزوكي .',
#   'label': 'Gulf'},
#  {'text': 'انا على هايوي ون، عند مورو بي.',
#   'translation': 'أنا على الطريق الرئيسي بجانب خليج موروا .',
#   'label': 'Gulf'},
#  {'text': 'اي عندنا. دورة نص يوم ودورة يوم كامل.',
#   'translation': 'نعم ، نحن لدينا . منهج نصف يوم ، ومنهج ليوم كامل .',
#   'label': 'Gulf'},
#  {'text': 'انا اقول حلق.', 'translation': 'أحبذ حلق .', 'label': 'Gulf'},
#  {'text': 'بغيت ساعة منبه لو سمحت.',
#   'translation': 'أريد منبه ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'بغيت اكنسل حجزي لو سمحت.',
#   'translation': 'أريد إلغاء حجزي ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'شنو نظام الاسترجاع عندكم؟',
#   'translation': 'ما هو نظام الاسترداد ؟',
#   'label': 'Gulf'},
#  {'text': 'الليتات ما تشتغل.',
#   'translation': 'الإضاءة لا تعمل .',
#   'label': 'Gulf'},
#  {'text': 'على فكرة، اسمي هيروشي ايجيما.',
#   'translation': 'بالمناسبة ، اسمي هيروش إيجيما .',
#   'label': 'Gulf'},
#  {'text': 'شنو فرق التوقيت بين طوكيو وهني؟',
#   'translation': 'ما هو فارق التوقيت بين طوكيو وهنا ؟',
#   'label': 'Gulf'},
#  {'text': 'القطار يوقف عند ليك فوريست صح؟',
#   'translation': 'هذا القطار يتوقف في لاك فورست , أليس كذلك ؟',
#   'label': 'Gulf'},
#  {'text': 'بكم كامل؟', 'translation': 'كم السعر الإجمالي ؟', 'label': 'Gulf'},
#  {'text': 'شكراً اخوي.', 'translation': 'شكراً يا سيدي .', 'label': 'Gulf'},
#  {'text': 'روح سيده وخذ ثالث لفة يمين.',
#   'translation': 'تقدم للأمام اتجه يمنياً عند الناصية الثالثة .',
#   'label': 'Gulf'},
#  {'text': 'فيني الم حاد في معدتي.',
#   'translation': 'أشعر بألم حاد في معدتي .',
#   'label': 'Gulf'},
#  {'text': 'اكثر اليابانيين ياكلون الاخطبوط والحبار.',
#   'translation': 'معظم اليابانيين يأكلون الأخطبوط والحبار .',
#   'label': 'Gulf'},
#  {'text': 'شفته؟', 'translation': 'هل رأيت ذلك ؟', 'label': 'Gulf'},
#  {'text': 'هذي هدية. ممكن تغلفها؟',
#   'translation': 'أنها هدية . هل يمكنك أن تقوم بلف هذه الهدية لي .',
#   'label': 'Gulf'},
#  {'text': 'مسا الخير، سيد كنت. من زمان ما شفتك.',
#   'translation': 'مساء الخير ، السيدة كنت . لم نلتقي منذ زمن بعيد .',
#   'label': 'Gulf'},
#  {'text': 'بغيت تذكرتين درجة ثانية لي شيكاغو؟',
#   'translation': 'هل يمكنني الحصول على تذكرتين درجة ثانية لشيكاغوا , من فضلك ؟',
#   'label': 'Gulf'},
#  {'text': 'الشرف لي.', 'translation': 'أنا أسعد .', 'label': 'Gulf'},
#  {'text': 'رحت نيويورك.',
#   'translation': 'لقد ذهبت إلى نيويورك .',
#   'label': 'Gulf'},
#  {'text': 'ابغي اغير حجزي لرحلة ميتين وخمسة تاريخ اثنين اكتوبر.',
#   'translation': 'أود أن أغير حجزي إلي الرحلة الجوية رقم اثنان صفر خمسة في الثاني من أكتوبر .',
#   'label': 'Gulf'},
#  {'text': 'شنو رقم الرحلة؟',
#   'translation': 'ما هو رقم الرحلة الجوية ؟',
#   'label': 'Gulf'},
#  {'text': 'وين كاونتر الجيك ان مال دلتا؟',
#   'translation': 'أين طاولة التسجيل الخاصة بشركة دلتا ؟',
#   'label': 'Gulf'},
#  {'text': 'هذي وجبة قليلة الصوديوم؟',
#   'translation': 'هل هذه وجبة منخفضة الصوديوم ؟',
#   'label': 'Gulf'},
#  {'text': 'هالغرض ممنوع.',
#   'translation': 'هذا البند غير مسموح به .',
#   'label': 'Gulf'},
#  {'text': 'اتوقع ان نقدر. تفضل هذي رصيدك.',
#   'translation': 'أعتقد أننا نستطيع . ها هي ورقتك .',
#   'label': 'Gulf'},
#  {'text': 'شنو آخر شي تفصخه قبل ما تروح السرير؟',
#   'translation': 'ما هو أخر شئ خلعته من ملابسك , قبل أن تذهب للنوم ؟',
#   'label': 'Gulf'},
#  {'text': 'لا، باخذه خلال اقامتي.',
#   'translation': 'لا ، سوف أخذها خلال فترة إقامتي .',
#   'label': 'Gulf'},
#  {'text': 'لونه ما يطير؟',
#   'translation': 'هل هو ثابت اللون ؟',
#   'label': 'Gulf'},
#  {'text': 'هذي خاص بهالمنطقة؟',
#   'translation': 'هل هذه خاصية خاصة بهذا الحي ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت بسكوت لو سمحت.',
#   'translation': 'أريد بعض البسكويت .',
#   'label': 'Gulf'},
#  {'text': 'واحد حق نيويورك لو سمحت.',
#   'translation': 'واحد لنيويورك ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'يعني حق كم يوم.',
#   'translation': 'لعدة أيام قليلة .',
#   'label': 'Gulf'},
#  {'text': 'ثاني واحد على اليسار.',
#   'translation': 'الثاني من على اليسار .',
#   'label': 'Gulf'},
#  {'text': 'واجد صغار.',
#   'translation': 'يبدون في حجم صغير جداً .',
#   'label': 'Gulf'},
#  {'text': 'شلون صعوبة الجولات؟',
#   'translation': 'كيف كانت صعوبة الجولات ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت كرسي يم الدريشة.',
#   'translation': 'أريد مقعد بالقرب من النافذة , من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'يصير ادخل بيوريلباس؟',
#   'translation': 'هل أستطيع أن أركب القطار بتذكرة اشتراك ركوب القطار الأوروبي ؟',
#   'label': 'Gulf'},
#  {'text': 'كم تاخذ الرحلة لليابان؟',
#   'translation': 'كم تستغرق كي تصل إلي اليابان ؟',
#   'label': 'Gulf'},
#  {'text': 'عندكم خرايط للطريق؟',
#   'translation': 'هل لديك خرائط للطرق ؟',
#   'label': 'Gulf'},
#  {'text': 'اي، قريت عنه في الدليل.',
#   'translation': 'أو ، نعم . لقد قرأت عنه في الدليل .',
#   'label': 'Gulf'},
#  {'text': 'طلبت ثلاث اكواب شاهي. وبس عطيتونا اثنين.',
#   'translation': 'لقد طلبت ثلاثة أكواب من الشاي . لكن لم يأتي ألا أثنين فقط .',
#   'label': 'Gulf'},
#  {'text': 'الاجهزة الكهربائية واجد رخيصة، بس الاكل ومصاريف السكن واجد عالية.',
#   'translation': 'الأجهزة الكهربائية رخيصة جداً , لكن مصاريف الأكل والسكن مرتفعة جداً .',
#   'label': 'Gulf'},
#  {'text': 'تيك اوي.', 'translation': 'سأتناولها بالخارج .', 'label': 'Gulf'},
#  {'text': 'انا عادةً آخذ مقاس اثنين وعشرين في اليابان.',
#   'translation': 'غالباً ما أخذ مقاس اثنتي وعشرين في اليابان .',
#   'label': 'Gulf'},
#  {'text': 'شنو ساعات متحف الفن؟',
#   'translation': 'ما هي ساعات عمل متحف الفن ؟',
#   'label': 'Gulf'},
#  {'text': 'وين ادفع؟',
#   'translation': 'أين يجب أن أدفع أدفع ؟',
#   'label': 'Gulf'},
#  {'text': 'هذي البطاقة، اوكي؟',
#   'translation': 'هذا الكارت , حسناً ؟',
#   'label': 'Gulf'},
#  {'text': 'هذي اول رحلة لك برع؟',
#   'translation': 'هل هذه هي أول رحلة خارجية لك ؟',
#   'label': 'Gulf'},
#  {'text': 'أي وحدة دورة المبتدئين؟',
#   'translation': 'أيهما الخاص بمنهج المبتدئين ؟',
#   'label': 'Gulf'},
#  {'text': 'هالدولة فيها وايد انواع من الفواكه.',
#   'translation': 'بالتأكيد هذا البلد به أكثر من نوع من الفاكهة .',
#   'label': 'Gulf'},
#  {'text': 'بغيت اسجل هالشنطة.',
#   'translation': 'أريد التثبت من هذه الحقيبة .',
#   'label': 'Gulf'},
#  {'text': 'متوفرة الوجبات في مكان التزلج بذاك المنحدر؟',
#   'translation': 'هل هناك وجبات في مكان التزلج فوق هذا المنحدر ؟',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت، انقفل باب شقتي، ممكن تعطيني مفتاح ثاني؟',
#   'translation': 'معذرة ، لقد أغلقت الباب وأنا بالخارج ، هل من الممكن أن أحصل على مفتاح أخر ؟',
#   'label': 'Gulf'},
#  {'text': 'حول لي هذي الدولارات الامريكية للين الياباني اذا ممكن.',
#   'translation': 'حول هذه الدولارات الأمريكية إلي الين ياباني ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'الفراق صعب.',
#   'translation': 'من الصعب قول كلمة وداعاً .',
#   'label': 'Gulf'},
#  {'text': 'هذي مكتب الاستقبال؟ في عيادة قريبة؟',
#   'translation': 'هل هذا مكتب الاستقبال ؟ هل يوجد عيادة قريبة ؟',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت، شنو طلبت؟ شكله لذيذ.',
#   'translation': 'معذرة ، هل لي أن أستفسر منك عن أسم طبقك ؟ إنه يبدو لذيذاً .',
#   'label': 'Gulf'},
#  {'text': 'يقرصون.', 'translation': 'أنهم يألمومنني .', 'label': 'Gulf'},
#  {'text': 'اي بوابة اروح بعدين؟',
#   'translation': 'أية بوابة أتوجه إليها بعد ذلك ؟',
#   'label': 'Gulf'},
#  {'text': 'تكفي عشر دولارات حق التكسي؟',
#   'translation': 'هل عشرة دولارات ستكون كافية للذهب بالتاكسي ؟',
#   'label': 'Gulf'},
#  {'text': 'برايي التمثيل كان ممتاز والقصة واجد زينة.',
#   'translation': 'أعتقد أنها كانت ممتازة . تمثيل جيد وحبكة جيدة .',
#   'label': 'Gulf'},
#  {'text': 'اوه، مشكور واجد.',
#   'translation': 'يا ، شكراً جزيلاً .',
#   'label': 'Gulf'},
#  {'text': 'ما عجبتني هالغرفة. يصير توريني وحدة ثانية؟',
#   'translation': 'لم تعجبني هذه الحجرة . هل من الممكن أن أرى حجرة أخرى ؟',
#   'label': 'Gulf'},
#  {'text': 'هذي آخر موضة هالصيف.',
#   'translation': 'أنها أحدث موضة هذا الصيف .',
#   'label': 'Gulf'},
#  {'text': 'ودني مركز المدينة لو سمحت.',
#   'translation': 'أذهب بي إلى وسط المدينة ، من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'ممكن أأجر سيارة؟',
#   'translation': 'هل لي أن أؤجر سيارة ؟',
#   'label': 'Gulf'},
#  {'text': 'طعمه غريب.', 'translation': 'أنه ذو مذاق غريب .', 'label': 'Gulf'},
#  {'text': 'لو سمحت صلحه وانا برع.',
#   'translation': 'قم بإصلاحها أثناء وجودي بالخارج من فضللك .',
#   'label': 'Gulf'},
#  {'text': 'عندك وجبة خفيفة؟',
#   'translation': 'هل لديكم وجبات خفيفة ؟',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت تكلم شوي شوي.',
#   'translation': 'من فضلك تحدث ببطء .',
#   'label': 'Gulf'},
#  {'text': 'بايي ساعة متأخر.',
#   'translation': 'سوف أحضر متأخرا ساعة .',
#   'label': 'Gulf'},
#  {'text': 'انا كين.', 'translation': 'أنا كن .', 'label': 'Gulf'},
#  {'text': 'اي. انتظر، بجيب لك واحد.',
#   'translation': 'نعم . انتظر , سوف احضر لك واحدة .',
#   'label': 'Gulf'},
#  {'text': 'قرسون.', 'translation': 'نادل .', 'label': 'Gulf'},
#  {'text': 'تم المطر يطق طول الاسبوع؟',
#   'translation': 'هل ستمطر طوال هذا الأسبوع ؟',
#   'label': 'Gulf'},
#  {'text': 'نص غرشة لو سمحت.',
#   'translation': 'نصف زجاجة , من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'يسوون عروض لايف؟',
#   'translation': 'هل لديهم عروض حية ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن اشوف ذيج الشنطة؟',
#   'translation': 'هل بإمكاني رؤية هذه الحقيبة ؟',
#   'label': 'Gulf'},
#  {'text': 'عندك شي غير؟', 'translation': 'هل لديك شيء آخر ؟', 'label': 'Gulf'},
#  {'text': 'تحتاج راحة.', 'translation': 'أنت بحاجة للراحة .', 'label': 'Gulf'},
#  {'text': 'لو سمحت املي بطاقة الهبوط هذي واستمارة الجمارك.',
#   'translation': 'من فضلك إملأ بطاقة الوصول التالية واستمارة الجمارك .',
#   'label': 'Gulf'},
#  {'text': 'تروح هالسيارة سياتل؟',
#   'translation': 'هل هذه السيارة متجهة إلى سيتل ؟',
#   'label': 'Gulf'},
#  {'text': 'ادفع جزء من المبلغ الحين؟',
#   'translation': 'هل يمكنني دفع جزء من الرسوم الآن ؟',
#   'label': 'Gulf'},
#  {'text': 'صجي او صناعي؟',
#   'translation': 'هي طبيعي أم اصطناعي ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن تنتظرني هني؟',
#   'translation': 'هل ستنتظرني هنا ؟',
#   'label': 'Gulf'},
#  {'text': 'اوه شكراً، توني ادوره.',
#   'translation': 'آه شكراً كنت أبحث عنها منذ قليل .',
#   'label': 'Gulf'},
#  {'text': 'كاش او شحن بطاقة؟',
#   'translation': 'نقداً أم على بطاقة الائتمان ؟',
#   'label': 'Gulf'},
#  {'text': 'انا مو من اهل هالمكان.',
#   'translation': 'أنا غريب تماماً على هذا المكان .',
#   'label': 'Gulf'},
#  {'text': 'لا. بس شي مو غالي.',
#   'translation': 'ليس تماماً . فقط شيء ما غير غالي الثمن .',
#   'label': 'Gulf'},
#  {'text': 'عادي ينغسل بالغسالة أو باليد في البيت؟',
#   'translation': 'هل يمكن أن يتم غسيلها في المغسلة أم يدوياً في المنزل ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت ألوان مائية لو سمحت.',
#   'translation': 'أحتاج علبة ألوان مائية من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'مسامحة، شنو بغيت؟',
#   'translation': 'آسف . ماذا كنت تريد ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت اغير التاريخ لي تسعطعش مايو.',
#   'translation': 'أود أن أغير الميعاد إلى التاسع عشر من مايو .',
#   'label': 'Gulf'},
#  {'text': 'وقع هني لو سمحت، وتفضل رصيدك حق المراجعة.',
#   'translation': 'من فضلك وقع هنا . وهذه فاتورة بمصروفاتك .',
#   'label': 'Gulf'},
#  {'text': 'بغيت دلاغات.',
#   'translation': 'أريد بعض الجوارب الحريمي .',
#   'label': 'Gulf'},
#  {'text': 'بغيت لحم عجل.',
#   'translation': 'احتاج بعض لحوم الضأن .',
#   'label': 'Gulf'},
#  {'text': 'تدور شي؟', 'translation': 'هل تبحث عن شيء ما ؟', 'label': 'Gulf'},
#  {'text': 'بغيت اركب في باص لمحطة بين. أي واحد اركب؟',
#   'translation': 'أود أن تقلني الحافلة المتجهة إلى محطة بين فأي الحافلات أركب ؟',
#   'label': 'Gulf'},
#  {'text': 'اربع ليالي.', 'translation': 'أربع ليالي .', 'label': 'Gulf'},
#  {'text': 'احتاج دلاغات.',
#   'translation': 'أريد بعض الجوارب الرجالي .',
#   'label': 'Gulf'},
#  {'text': 'ما فيها الا شوية سعرات حرارية. بس ثلاثين.',
#   'translation': 'سعراتها الحرارية منخفضة جدا . فقط 30 سعر .',
#   'label': 'Gulf'},
#  {'text': 'بغيت احجز غرفة.',
#   'translation': 'أريد أن أحجز غرفة .',
#   'label': 'Gulf'},
#  {'text': 'من وين بالضبط في اليابان؟',
#   'translation': 'من أي مكان في اليابان أنت ؟',
#   'label': 'Gulf'},
#  {'text': 'للأسف، بيكون وايد مشغول في هاليوم.',
#   'translation': 'لسوء الحظ هو مشغول جداً في ذلك اليوم .',
#   'label': 'Gulf'},
#  {'text': 'في هالحالة، اقترح عليك هذي.',
#   'translation': 'في هذه الحالة ، أنصح بهذه الواحدة .',
#   'label': 'Gulf'},
#  {'text': 'خدمة الغرف.', 'translation': 'خدمة حجرة .', 'label': 'Gulf'},
#  {'text': 'انتبهوا لو سمحتوا.',
#   'translation': 'انتبهوا من فضلكم .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تخليها ارخص لأن فيها بقع؟',
#   'translation': 'هل تستطيع أن تخفض سعرها لوجود بعض البقع بها ؟',
#   'label': 'Gulf'},
#  {'text': 'عندك طوابع تذكارية؟',
#   'translation': 'هل لديك أية طوابع تذكارية ؟',
#   'label': 'Gulf'},
#  {'text': 'هذي غرفة ثلاثمية وسبعطعش. ممكن احصل لحاف ثاني؟',
#   'translation': 'هذه غرفة ثلاثة سبعة عشر . يمكنني أخذ بطانية أخرى ؟',
#   'label': 'Gulf'},
#  {'text': 'تقدر توصلني المحطة في خمسطعش دقيقة؟',
#   'translation': 'هل تستطيع أن توصلني إلى المحطة في خمس عشرة دقيقة .',
#   'label': 'Gulf'},
#  {'text': 'نحتاج عربون للسيارة.',
#   'translation': 'نحتاج رهن للعربة .',
#   'label': 'Gulf'},
#  {'text': 'ريال صدمني. بعدها اكتشفت ان بوكي اختفى.',
#   'translation': 'ارتطم بي شخص وبعد ذلك اكتشفت أن محفظتي قد سرقت .',
#   'label': 'Gulf'},
#  {'text': 'ما عندنا غرف فردية فاضية بس في غرفة دبل.',
#   'translation': 'لا يوجد أماكن شاغرة بالغرف ذات السرير الواحد ولكن توجد أماكن شاغرة بالغرف المزدوجة .',
#   'label': 'Gulf'},
#  {'text': 'التذكرة هذي صالحة بس حق اليوم المحدد؟',
#   'translation': 'هل هذه التذكرة سارية فقط لليوم المحدد ؟',
#   'label': 'Gulf'},
#  {'text': 'متى يوصل ميلانو؟',
#   'translation': 'متى تصل إلى ميلانو ؟',
#   'label': 'Gulf'},
#  {'text': 'عندك احد يتكلم ياباني؟',
#   'translation': 'هل لديكم شخص يتحدث اليابانية ؟',
#   'label': 'Gulf'},
#  {'text': 'على أي قناة يحطون الموسيقى الهابة؟',
#   'translation': 'ما هي المحطة التي تذاع عليها الموسيقي الشعبية ؟',
#   'label': 'Gulf'},
#  {'text': 'طيران دلتا.',
#   'translation': 'شركة الخطوط الجوية دلتا .',
#   'label': 'Gulf'},
#  {'text': 'بغيت دلة قهوة.',
#   'translation': 'أريد إبريق قهوة .',
#   'label': 'Gulf'},
#  {'text': 'فيه حمام ومرحاض؟',
#   'translation': 'هل تحتوي على حمام ومرحاض ؟',
#   'label': 'Gulf'},
#  {'text': 'خلص الوقت.', 'translation': 'الوقت انتهى .', 'label': 'Gulf'},
#  {'text': 'سمعت ان سيد يامادا عنده طفلين.',
#   'translation': 'سمعت أنا السيد يامادا عنده ولدان .',
#   'label': 'Gulf'},
#  {'text': 'بغيت أأجر قارب شراعي.',
#   'translation': 'أود أن أستأجر قارب شراعي .',
#   'label': 'Gulf'},
#  {'text': 'يصير تغسل الصحون بعدين؟',
#   'translation': 'هل بإمكانك عمل الأطباق في وقت لاحق ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت جولة.', 'translation': 'أريد موقد غاز .', 'label': 'Gulf'},
#  {'text': 'تقدر تحول دولارات امريكية لجنيهات استرلينية؟',
#   'translation': 'هل يمكنك تغيير الدولارات الأمريكية إلى جنيهات إسترلينية ؟',
#   'label': 'Gulf'},
#  {'text': 'اكيد اخوي. اسمك؟',
#   'translation': 'بالتأكيد يا سيدي . ما اسمك ؟',
#   'label': 'Gulf'},
#  {'text': 'مو لابس رسمي.',
#   'translation': 'لست مرتديا للزي الرسمي .',
#   'label': 'Gulf'},
#  {'text': 'ارجوك بس جيب روحك المرة الياية.',
#   'translation': 'ارجوا أن تحضر المرة القادمة فقط .',
#   'label': 'Gulf'},
#  {'text': 'مادري اذا جهزت ثياب تكفي حق رحلة مدتها ثلاث اسابيع.',
#   'translation': 'أنا غير متأكد إذا كنت قد حزمت ملابس كافية لرحلة مدتها ثلاثة أيام .',
#   'label': 'Gulf'},
#  {'text': 'كل واحد دولارين.',
#   'translation': 'دولاران لكل واحدة .',
#   'label': 'Gulf'},
#  {'text': 'بنتأكد ان تنرسل لك النشرات.',
#   'translation': 'لقد تأكدنا جميعا من أن الكراسات قد أرسلت إليكم عن طريق البريد .',
#   'label': 'Gulf'},
#  {'text': 'في شي غلط فليتات البريك.',
#   'translation': 'ثمة عطل ما بالكاشفات الخلفية .',
#   'label': 'Gulf'},
#  {'text': 'ورني قفازات جلد لو سمحت.',
#   'translation': 'أرني بعض القفازات الجلدية من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'السيارة اختربت. لو سمحت طرش لها احد.',
#   'translation': 'لقد تعطلت العربة . من فضلك أرسل شخص لإصلاحها .',
#   'label': 'Gulf'},
#  {'text': 'اقترح لي كتاب فيه صور حق ياهل عمره ست سنين؟',
#   'translation': 'هل بإمكانك أن تزكي لي كتاباً مصوراً لطفل يبلع من العمر 6 سنوات ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن تحفظ اشيائي الغالية، لو سمحت؟',
#   'translation': 'هل من الممكن أن تحفظ أشيائي الثمينة من فضلك ؟',
#   'label': 'Gulf'},
#  {'text': 'مرحبا هاري. شكراً على العزيمة.',
#   'translation': 'مرحباً هاري . أشكرك على دعوتك لنا .',
#   'label': 'Gulf'},
#  {'text': 'انزين، نبي نجرب واين ابيض.',
#   'translation': 'حسناً ، أود أن أجرب النبيذ الأبيض .',
#   'label': 'Gulf'},
#  {'text': 'لما يواعدون، يروحون السينما.',
#   'translation': 'إنهم في السينما حتى وقتنا هذا .',
#   'label': 'Gulf'},
#  {'text': 'كان عندي مية دولار فيها تقريباً.',
#   'translation': 'معي بها حوالي ألف دولار .',
#   'label': 'Gulf'},
#  {'text': 'غلطتي.', 'translation': 'خطئي .', 'label': 'Gulf'},
#  {'text': 'بغيت مشابك للغسيل.',
#   'translation': 'احتاج لبعض مشابك الغسيل .',
#   'label': 'Gulf'},
#  {'text': 'أي سيديات مستوردة؟',
#   'translation': 'أية أقراص مدمجة مستوردة ؟',
#   'label': 'Gulf'},
#  {'text': 'بدرس المحادثة الانجليزية.',
#   'translation': 'سوف ادرس المحادثة بالإنجليزية .',
#   'label': 'Gulf'},
#  {'text': 'قريت اي كتب زينة في الفترة الاخيرة؟',
#   'translation': 'هل قرأت أية كتب جيدة حديثاً ؟',
#   'label': 'Gulf'},
#  {'text': 'بتم مع صديقي في نيويورك.',
#   'translation': 'سوف أقيم مع صديق في نيويورك .',
#   'label': 'Gulf'},
#  {'text': 'اذا احد سأل عني، قول لهم انا في الكوفي شوب.',
#   'translation': 'إذا سأل أحد عني فأخبره بأني سوف أكون بالمقهى .',
#   'label': 'Gulf'},
#  {'text': 'انا متأكد ان كان موجود في جيب كوتي الداخلي.',
#   'translation': 'أنا متأكد أني وضعتها بالجيب الداخلي للمعطف .',
#   'label': 'Gulf'},
#  {'text': 'عندك مكان احط فيه شناطي؟',
#   'translation': 'هل عندك مكان من الممكن أن أترك فيه أمتعتي ؟',
#   'label': 'Gulf'},
#  {'text': 'ييت هني حق شغل.',
#   'translation': 'أتيت إلى هنا في عمل .',
#   'label': 'Gulf'},
#  {'text': 'تعرف مدارس غوص زينة؟',
#   'translation': 'هل تعرف أية مدرسة غوص جيدة ؟',
#   'label': 'Gulf'},
#  {'text': 'كم يصير السعر مع الضرايب؟',
#   'translation': 'كم يكون السعر شاملاً الضرائب ؟',
#   'label': 'Gulf'},
#  {'text': 'عطني كلينكس.',
#   'translation': 'أعطني بعض المناديل الورقية .',
#   'label': 'Gulf'},
#  {'text': 'الجيران واجد مزعجين.',
#   'translation': 'الشقة المجاورة كثيرة الضوضاء .',
#   'label': 'Gulf'},
#  {'text': 'دكتور كريبز ما يدخل احد بدون موعد.',
#   'translation': 'نعم ، دكتور كريبس لا يفحص أي مريض بدون موعد مسبق .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تعطيني اسم ورقم الشخص اللي تكلمه؟',
#   'translation': 'هل يمكن أن تخبرين باسم ورقم الطرف الذي تريد الاتصال به ؟',
#   'label': 'Gulf'},
#  {'text': 'هدية؟', 'translation': 'هل هذه هدية ؟', 'label': 'Gulf'},
#  {'text': 'الخطوط الجوية بتدفع لي عشان اشتري بعض الضروريات؟',
#   'translation': 'هل ستدفع لي شركة الطيران لشراء بعض الاحتياجات الشخصية الأساسية ؟',
#   'label': 'Gulf'},
#  {'text': 'بتروح القراند هوتيل؟',
#   'translation': 'هل هذه متجه إلى فندق جراند ؟',
#   'label': 'Gulf'},
#  {'text': 'محد هني بهالاسم.',
#   'translation': 'لا يوجد أحد هنا بهذا الاسم .',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت، وين الشرطي؟',
#   'translation': 'أين رجل الشرطة , من فضلك ؟',
#   'label': 'Gulf'},
#  {'text': 'يصير اتسلف تيب؟',
#   'translation': 'هل لي أن اقترض بعض الأشرطة اللاصقة ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت غرفة فيها حمام.',
#   'translation': 'أرغب في غرفة بحمام .',
#   'label': 'Gulf'},
#  {'text': 'ولا شي طلع من المكينة؟',
#   'translation': 'لم يخرج من الماكينة شيء .',
#   'label': 'Gulf'},
#  {'text': 'هذي مضمون؟', 'translation': 'هل هذا معه ضمان ؟', 'label': 'Gulf'},
#  {'text': 'شنو التشخيص؟', 'translation': 'ما هو تشخيصك ؟', 'label': 'Gulf'},
#  {'text': 'في نهاية الممر في الطابق السابع. خذ اللفت على يمينك.',
#   'translation': 'إنها بنهاية الممر الموجود بالطابق السابع . أركب المصعد الموجود على يمينك من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'احنا في محطة جونز ستريت.',
#   'translation': 'نحن في محطة " جونز ستريت " .',
#   'label': 'Gulf'},
#  {'text': 'كلش ما افكر اروح لحفل كلاسيكي وانا في اليابان.',
#   'translation': 'لم أفكر أبداً في الذهاب إلى الحفلات الموسيقية الكلاسيكية عندما كنت في اليابان .',
#   'label': 'Gulf'},
#  {'text': 'شنو ايي في هالطبق؟',
#   'translation': 'هل يمكنك وصف هذا الطبق لي ؟',
#   'label': 'Gulf'},
#  {'text': 'كان المفروض تروح على الرحلة ثمانمية وعشرين اللي طارت من خمسطعش دقيقة. اقدر ارتب لك رحلة ثانية.',
#   'translation': 'كان يفترض أن تسافر على الطائرة رقم ثمانية اثنان صفر التي أقلعت منذ خمس عشرة دقيقة . حسنا . بإمكاني تنظيم رحلة أخرى .',
#   'label': 'Gulf'},
#  {'text': 'تفضل. مقاعدكم هالصوب.',
#   'translation': 'إنها هنا . مقاعدكم تقع بالقرب من هنا .',
#   'label': 'Gulf'},
#  {'text': 'هو في رحلة عمل ليوم الجمعة الجاية.',
#   'translation': 'هو في رحلة عمل حتى يوم الجمعة القادم .',
#   'label': 'Gulf'},
#  {'text': 'انا وزوجتي وايد مستانسين لانكم بتقعدون ويانا في الويكند عشان تتعرفون على الحياة الأمريكية في الريف.',
#   'translation': 'أنا وزوجتي سعداء جداً لأنك قادم لتقضي معنا نهاية الأسبوع حتى تجرب الحياة الأمريكية في الريف .',
#   'label': 'Gulf'},
# ...
#  {'text': 'بكم حق شخصين؟',
#   'translation': 'كم السعر لفردين ؟',
#   'label': 'Gulf'},
#  {'text': 'مرة وحدة جاني مغص في بطني.',
#   'translation': 'أصبت بمغص فجأة .',
#   'label': 'Gulf'},
#  {'text': 'كم ياخذ المرشد لليوم؟',
#   'translation': 'كم يتقاضى المرشد في اليوم ؟',
#   'label': 'Gulf'},
#  {'text': 'اسمي هيروشي موري.',
#   'translation': 'اسمي هيروشي موري .',
#   'label': 'Gulf'},
#  {'text': 'بغيت روب، لو سمحت.',
#   'translation': 'أريد بعض الزبادي من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'اي. هذي هو الكاونتر حق رحلة طيران يونايتد رقم ثمانمية وعشرين؟',
#   'translation': 'نعم . هل هذه هي الطاولة الصحيحة للخطوط الجوية المتحدة رحلة ثمانية اثنين صفر ؟',
#   'label': 'Gulf'},
#  {'text': 'لازم نلبس كوت وربطة؟',
#   'translation': 'هل ينبغي علينا ارتداء معاطف ورابطات عنق ؟',
#   'label': 'Gulf'},
#  {'text': 'اي باص يروح قيلد هول؟',
#   'translation': 'ما الاتوبيس الذي يذهب إلى قاعة جيلد ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت واحد يكفي وثائق بحجم اوراق الرسايل بدون ما اطويهم.',
#   'translation': 'أريد الشخص الذي يعد وثائق عادية في حجم ورقة الخطاب بدون الحاجة إلى طيهم .',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت تعال من هني، خلني اساعدك مع اغراضك.',
#   'translation': 'من فضلك تعال من هذا الطريق . دعني أساعدك في حمل حقائبك .',
#   'label': 'Gulf'},
#  {'text': 'في ثاني رف في الصفة الوسطية.',
#   'translation': 'إنها على الرف الثاني في الصف الأوسط .',
#   'label': 'Gulf'},
#  {'text': 'وين البار؟', 'translation': 'أين البار ؟', 'label': 'Gulf'},
#  {'text': 'لو سمحت سو جيك ان قبل تسع وتسع دقايق الصبح.',
#   'translation': 'من فضلك سجل اسمك قبل تسعة صفر تسعة صباحا .',
#   'label': 'Gulf'},
#  {'text': 'كراسينا مفرقين.',
#   'translation': 'مقاعدنا منفصلة .',
#   'label': 'Gulf'},
#  {'text': 'اكيد. وين تبغي تروح؟',
#   'translation': 'بالتأكيد . أين تريد أن تذهب ؟',
#   'label': 'Gulf'},
#  {'text': 'اي، بس مو وايد قوي.',
#   'translation': 'نعم ، لكن ليس قويا جدا .',
#   'label': 'Gulf'},
#  {'text': 'فيني حساسية من القطاوة.',
#   'translation': 'أنا شديد الحساسية للقطط .',
#   'label': 'Gulf'},
#  {'text': 'بغيت مذكرة، لو سمحت.',
#   'translation': 'أريد دفتر لتسجيل من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'اي، لازم يكون عندك ليسن و، اه، لازم يكون عندك ليسن من وكالة التكسي والليموزين.',
#   'translation': 'نعم , لا بد أن يكون عندك رخصة قيادة ، ولا بد أن تحصل على رخصة من لجنة التاكسي والليموزين .',
#   'label': 'Gulf'},
#  {'text': 'ان شاء الله تستانس.', 'translation': 'وقت سعيد .', 'label': 'Gulf'},
#  {'text': 'آسف، كل الكراسي محجوزة في ثلطعش اغسطس.',
#   'translation': 'آسف ، كل المقاعد مشغولة في الثلاثين من أغسطس .',
#   'label': 'Gulf'},
#  {'text': 'ممكن اشوف شي ارخص؟',
#   'translation': 'هل يمكن أن أرى شيئا أرخص .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تكلم لي تكسي؟',
#   'translation': 'هل من الممكن أن تستدعي تاكسيا لي ؟',
#   'label': 'Gulf'},
#  {'text': 'لازم ارجع اليابان الحين؟',
#   'translation': 'هل أنا بحاجة للعودة فورا إلى اليابان ؟',
#   'label': 'Gulf'},
#  {'text': 'سعر الغرفة اغلى من اللي انقال لي.',
#   'translation': 'مصاريف الغرفة أغلى مما أُخبرت .',
#   'label': 'Gulf'},
#  {'text': 'بغيت اعطيك طلب زيادة. ممكن اشوف المنيو مرة ثانية؟',
#   'translation': 'أود أن أطلب طلب آخر . هل من الممكن أن أرى قائمة الطعام مرة أخرى ؟',
#   'label': 'Gulf'},
#  {'text': 'كان في حمالة مفاتيح على قطو ملصوقة بشريطة هني.',
#   'translation': 'كان هناك ميدالية مفاتيح على شكل قطة معلقة في شريط هنا .',
#   'label': 'Gulf'},
#  {'text': 'شبتسوي بهالشنطة الصغيرة؟',
#   'translation': 'ماذا ستفعل مع هذه الحقيبة الصغيرة ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت شي حق الزكام.',
#   'translation': 'أريد شيئا للبرد .',
#   'label': 'Gulf'},
#  {'text': 'ممكن اشوف هذيج؟',
#   'translation': 'هل من الممكن أن أرى هذا ؟',
#   'label': 'Gulf'},
#  {'text': 'ثمانطعش دولار بالضبط.',
#   'translation': 'ثمانية عشر دولارا بالضبط .',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت اصرف هالجيك السياحي عطني كاش.',
#   'translation': 'من فضلك اصرف هذا الشيك السياحي .',
#   'label': 'Gulf'},
#  {'text': 'وين احط غسيلي؟',
#   'translation': 'أين أضع الغسيل ؟',
#   'label': 'Gulf'},
#  {'text': 'خذت كفاية؟',
#   'translation': 'هل كان عندك الكفاية ؟',
#   'label': 'Gulf'},
#  {'text': 'تفضل، اخوي.', 'translation': 'استمر يا سيدي .', 'label': 'Gulf'},
#  {'text': 'روح سيده على هالشارع. هو بالضبط قبل محل الايسكريم.',
#   'translation': 'امشي إلى آخر هذا الشارع . إنها قبل محل الأيس كريم مباشرة .',
#   'label': 'Gulf'},
#  {'text': 'مو محصل ماي حار.',
#   'translation': 'يبدوا أنني غير قادر على الحصول على الماء الساخن .',
#   'label': 'Gulf'},
#  {'text': 'ما عندي حجز.', 'translation': 'ليس عندي حجز .', 'label': 'Gulf'},
#  {'text': 'عادي ايوده؟',
#   'translation': 'هل يمكن أن ألمسها ؟',
#   'label': 'Gulf'},
#  {'text': 'أشر وينه على هالخريطة، لو سمحت.',
#   'translation': 'أشر على مكانها على الخريطة من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'في مطاعم زينة ورخيصة هني؟',
#   'translation': 'هل هناك مطاعم رخيصة وجيدة قريبة من هنا ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت احجز غرفة حق الليلة.',
#   'translation': 'أود أن أحجز غرفة لهذه الليلة .',
#   'label': 'Gulf'},
#  {'text': 'حلو هالبيت.', 'translation': 'هذا بيت رائع .', 'label': 'Gulf'},
#  {'text': 'هذي محطة الباص حق تشيلسي؟',
#   'translation': 'هل هذه هي المحطة للأتوبيس المتجهة إلى شيلسي ؟',
#   'label': 'Gulf'},
#  {'text': 'بسوي جيك ان متأخر شوي الليلة، بس خل حجزي لو سمحت.',
#   'translation': 'سوف أحضر إلى الفندق متأخر قليلا هذه الليلة , ولكن من فضلك أحتفظ بحجزي .',
#   'label': 'Gulf'},
#  {'text': 'عادي كردت كارد؟',
#   'translation': 'هل من الممكن استخدام البطاقة الائتمانية ؟',
#   'label': 'Gulf'},
#  {'text': 'اذا جا الجابي عشان يجيك تذكرتك، وره التصريح والتذكرة.',
#   'translation': 'عندما يأتي المحصل ليرى تذكرتك ، من فضلك أره جوازك وهذه التذكرة .',
#   'label': 'Gulf'},
#  {'text': 'كم قلم رصاص تحتاج؟',
#   'translation': 'ما عدا الأقلام الرصاص التي تحتاج ؟',
#   'label': 'Gulf'},
#  {'text': 'شنو آخر كتاب لقالبريث؟',
#   'translation': 'ما هو أحدث كتاب لجالبريث ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت كرسي في المقاعد العامة، لو سمحت.',
#   'translation': 'مقعد دخول واحد من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'طلبت نص مطبوخ، مو مطبوخ كلش.',
#   'translation': 'طلبت نصف طازج ، ليس ناضجا بالكامل .',
#   'label': 'Gulf'},
#  {'text': 'بدلتك بتجهز بعد اسبوع من اخذ المقاسات، اخوي.',
#   'translation': 'سيكون بدلتك جاهز بعد أسبوع من البروفة يا سيدي .',
#   'label': 'Gulf'},
#  {'text': 'لا، بدون الضريبة ورسوم الخدمة.',
#   'translation': 'لا ، إنها لا تشمل الضريبة ومصاريف الخدمة .',
#   'label': 'Gulf'},
#  {'text': 'بغيت عصير تفاح، وتوست، وبيض مقلي، وقهوة.',
#   'translation': 'أريد عصير تفاح وخبز محمص وبيض مقلي وقهوة .',
#   'label': 'Gulf'},
#  {'text': 'وين محل الكاميرات؟',
#   'translation': 'أين محل الكاميرات ؟',
#   'label': 'Gulf'},
#  {'text': 'كولا صغيرة، لو سمحت.',
#   'translation': 'واحد كوكاكولا صغير من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'انا توني مبتدئ، ماظن اقدر اسويه.',
#   'translation': 'أنما أنا مبتدئ . أعتقد أني لا أستطيع عمل ذلك .',
#   'label': 'Gulf'},
#  {'text': 'اربع تفاحات.', 'translation': 'أربع تفاحات .', 'label': 'Gulf'},
#  {'text': 'كم يكلف تأمينه على ثلاثمية دولار؟',
#   'translation': 'كم تكلف لتأمينها بثلاثمائة دولار ؟',
#   'label': 'Gulf'},
#  {'text': 'تبغي تروح معاي نتسوق الظهر؟',
#   'translation': 'هل تريد أن تذهب للتسوق معي بعد الظهر ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن تعيد اصدار الكردت كارد مالتي؟',
#   'translation': 'هل من الممكن أن تعيد إصدار بطاقتي الائتمانية ؟',
#   'label': 'Gulf'},
#  {'text': 'مرحبا، واجد حلو هالفستان.',
#   'translation': 'هيه ، هذا فستان جميل حقا .',
#   'label': 'Gulf'},
#  {'text': 'عطني وقت حق ارد افكر.',
#   'translation': 'اعطني بعض الوقت للتفكير .',
#   'label': 'Gulf'},
#  {'text': 'لازم ترتاح في السرير اليوم.',
#   'translation': 'يجب أن تستريح اليوم .',
#   'label': 'Gulf'},
#  {'text': 'بغيت ارد اتأكد من اللي لازم اسويه بالضبط.',
#   'translation': 'أريد أن أعيد تأكيد ما المفروض أن أفعله بالضبط .',
#   'label': 'Gulf'},
#  {'text': 'اعرف شتحس فيه. هد بالك.',
#   'translation': 'أعرف كيف تشعر ، هون عليك .',
#   'label': 'Gulf'},
#  {'text': 'برد اتصل.', 'translation': 'سوف أتصل مرة أخرى .', 'label': 'Gulf'},
#  {'text': 'الحين، مكالمتك وصلت. تفضل، لو سمحت.',
#   'translation': 'الآن ، مكالمتك ردت . تفضل من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تحجز طاولة حق شخصين في ذاك المطعم حق الساعة ست الليلة؟',
#   'translation': 'هل ستحجز مائدة لاثنين في هذا المطعم في السادسة هذه الليلة ؟',
#   'label': 'Gulf'},
#  {'text': 'غريب. شكله مخلوق فضائي.',
#   'translation': 'يا له من شيء غريب . إنه يبدو كطبق طائر في السماء .',
#   'label': 'Gulf'},
#  {'text': 'مو قادر انام عدل.',
#   'translation': 'لا أستطيع أن أنام جيدا .',
#   'label': 'Gulf'},
#  {'text': 'كم رقم البوابة؟',
#   'translation': 'ما رقم البوابة ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن تخبرني هالمبلغ حق شنو؟',
#   'translation': 'هل من الممكن من فضلك أن تخبرني عن أي شيء هذه الرسوم ؟',
#   'label': 'Gulf'},
#  {'text': 'شنو الهدية التقليدية من هاواي؟',
#   'translation': 'ما التذكار الخاص بهاواي ؟',
#   'label': 'Gulf'},
#  {'text': 'الو، هذي غرفة ثلاثمية وخمسة.',
#   'translation': 'مرحبا ، هذه غرفة ثلاثة صفر خمسة .',
#   'label': 'Gulf'},
#  {'text': 'بغيت املاح للشور.',
#   'translation': 'أريد بعض الأملاح للحمام .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تصلح هالكاميرا؟ ما تسوي لود عدل.',
#   'translation': 'هل من الممكن أن تصلح هذه الكاميرا ؟ إنها لا تسحب بشكل جيد .',
#   'label': 'Gulf'},
#  {'text': 'اسمك ورقمك؟', 'translation': 'ما اسمك ورقمك ؟', 'label': 'Gulf'},
#  {'text': 'انا عبالي السعر ثابت بين المطار ووسط المدينة؟',
#   'translation': 'فكرت أنه مقدار ثابت بين المطار ووسط المدينة .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تروح تجيك الحين؟ اذا هم هناك، ممكن تجيب كل شي هني الحين؟',
#   'translation': 'هلا تكرمت وذهبت وتأكدت منها الآن ؟ لو كانوا هناك ، هل ستحضر كل شيء هنا في الحال ؟',
#   'label': 'Gulf'},
#  {'text': 'اظن ان اسعار الصرف تتقلب بين التوقعات المرتفعة والنازلة، بشكل عام.',
#   'translation': 'حسنا ، أعتقد أن سعر الصرف يتقلب بين توقعات بالارتفاع والانخفاض عموما .',
#   'label': 'Gulf'},
#  {'text': 'له عادات وتاريخ قديمين.',
#   'translation': 'لها أصالة وتاريخ .',
#   'label': 'Gulf'},
#  {'text': 'شنو اللعبة الحالية في الاستاد؟',
#   'translation': 'ما اللعبة التي تلعب في الإستاد ؟',
#   'label': 'Gulf'},
#  {'text': 'شبتسوي راس السنة؟',
#   'translation': 'ماذا ستفعل في ليلة رأس السنة ؟',
#   'label': 'Gulf'},
#  {'text': 'اقدر اروح هناك في النفق؟',
#   'translation': 'أيمكنني أن أذهب هناك بمترو الأنفاق ؟',
#   'label': 'Gulf'},
#  {'text': 'هلا، ممكن تعطيني رقم تلفون السفارة او القنصلية اليابانية، لو سمحت؟',
#   'translation': 'هل من الممكن أن تعطني رقم السفارة أو القنصلية اليابانية من فضلك ؟',
#   'label': 'Gulf'},
#  {'text': 'هذيلين هم. وايد مريحين.',
#   'translation': 'إنها جيدة . إنها مريحة جدا .',
#   'label': 'Gulf'},
#  {'text': 'بغيت استشوار.', 'translation': 'أريد مجفف .', 'label': 'Gulf'},
#  {'text': 'والله هذي غرفة هادية. وايد زين.',
#   'translation': 'حسنا , هذه غرفة هادئة . جميلة جدا .',
#   'label': 'Gulf'},
#  {'text': 'بنوصل لأي نتيجة واحنا نتكلم جذي؟',
#   'translation': 'هل نذهب إلى أي مكان متحدثين مثل ذلك ؟',
#   'label': 'Gulf'},
#  {'text': 'عندي حجز الساعة سبع.',
#   'translation': 'عندي حجز في السابعة .',
#   'label': 'Gulf'},
#  {'text': 'عادي. بس بيكون في رسوم ميتين دولار حق التوصيل.',
#   'translation': 'هذا جيد . لكن سيكون هناك انخفاض في المصاريف مائتين دولار .',
#   'label': 'Gulf'},
#  {'text': 'الساعة سبع الصبح، بالتوقيت المحلي.',
#   'translation': 'في السابعة صباحا , التوقيت المحلي .',
#   'label': 'Gulf'},
#  {'text': 'هو في هذي الشارع تقريباً بعد ثلاث مجمعات، اظن.',
#   'translation': 'إنها في آخر هذا الشارع بعد ثلاثة عمارات كما أخمن .',
#   'label': 'Gulf'},
#  {'text': 'آسف، كله محجوز عشان اجازة الكرسمس، بس عندنا كرسي في واحد وعشرين ديسمبر.',
#   'translation': 'آسف , إنها محجوزة بالكامل لموسم أجازات عيد الميلاد ، لكن عندنا مقعد واحد في الثاني والعشرين من ديسمبر .',
#   'label': 'Gulf'},
#  {'text': 'فهمت. شكراً.', 'translation': 'فهمت . شكرا لك .', 'label': 'Gulf'},
#  {'text': 'احصل تعويض اذا ما حصلتوا شنطتي؟',
#   'translation': 'هل أحصل على تعويض إذا لم تجدوا حقيبتي ؟',
#   'label': 'Gulf'},
#  {'text': 'اوكي، شنو نوع الفواكه اللي تحبها؟',
#   'translation': 'حسنا . أي أنواع الفاكهة تحب ؟',
#   'label': 'Gulf'},
#  {'text': 'متى آخر مرة جاتج الدورة؟',
#   'translation': 'متى كان آخر حيض لك ؟',
#   'label': 'Gulf'},
#  {'text': 'انا ياي من النرويج.',
#   'translation': 'أنا من النرويج .',
#   'label': 'Gulf'},
#  {'text': 'انا اتصلت حق أأكد قبل يومين.',
#   'translation': 'عملت إعادة تأكيد بالتليفون منذ يومين .',
#   'label': 'Gulf'},
#  {'text': 'مو متأكد اذا جوازي انباق او طاح من جيبي.',
#   'translation': 'لست متأكدا ما إذا كان جواز سفري نُشل أم أنه ببساطة سقط من جيبي .',
#   'label': 'Gulf'},
#  {'text': 'طول الصندوق خمسة وستين سنتي، وعرضه ثلاثين، وارتفاعه ثمانطعش.',
#   'translation': 'طول الصندوق خمسة وستون سنتيمترا وعرضه ثلاثين سنتيمترا وارتفاعه ثمانية عشر سنتيمترا .',
#   'label': 'Gulf'},
#  {'text': 'ادور هدايا.', 'translation': 'أبحث عن تذكار .', 'label': 'Gulf'},
#  {'text': 'تتكون من اربع جزر رئيسية.',
#   'translation': 'إنها تحتوي علي أربعة جزر رئيسية .',
#   'label': 'Gulf'},
#  {'text': 'الساعة عشر. هذي مفتاح غرفتك. غرفتك خمسة آلاف واربعمية وثلاثة وثلاثين. حمال الشنط بيجيب لك شناطك فوق.',
#   'translation': 'الساعة العاشرة . هذا مفتاح غرفتك . غرفتك رقم أربعة وخمسون ثلاثة وثلاثون . الخادم سيأخذ حقائبك إلى أعلى .',
#   'label': 'Gulf'},
#  {'text': 'اي وايد مستانسين في هاواي. ياليتك معانا.',
#   'translation': 'نعم , نحن نقضي وقت جميل في هاواي . كنت أتمنى لو كنت هنا .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تعطيني ترجمة؟',
#   'translation': 'هل يمكنك أن تزودني بالترجمة ؟',
#   'label': 'Gulf'},
#  {'text': 'باخذ شاهي حليب.',
#   'translation': 'سوف أتناول بعض الشاي مع اللبن .',
#   'label': 'Gulf'},
#  {'text': 'يصير تقص قذلتي نص انج فوق حواجبي؟',
#   'translation': 'هل ممكن أن تحف شعري نصف بوصة فوق الحاجب ؟',
#   'label': 'Gulf'},
#  {'text': 'من عشر لي اثنعش لو سمحت.',
#   'translation': 'من ثمانية إلى اثنى عشر من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'متى يفتح؟', 'translation': 'متى يفتح ؟', 'label': 'Gulf'},
#  {'text': 'عندك غرف بأقل من خمسين دولار حق الليلة؟',
#   'translation': 'هل عندك غرف بأقل من خمسين دولارا في الليلة ؟',
#   'label': 'Gulf'},
#  {'text': 'طاولة لشخصين حق الساعة ست المسا، لو سمحت.',
#   'translation': 'مائدة لفردين في السادسة هذا المساء من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'بقيمة خمسطعش دولار، لو سمحت.',
#   'translation': 'بقيمة خمسة عشر دولار من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'لف يسار مع الليت.',
#   'translation': 'انعطف يسارا عند الضوء الوامض .',
#   'label': 'Gulf'},
#  {'text': 'ما احتاج شي.', 'translation': 'لا أحتاج أي شيء .', 'label': 'Gulf'},
#  {'text': 'ممكن اسوي حجز حق جولة سياحية؟',
#   'translation': 'هل من الممكن أن أحجز في جولة سياحية استطلاعية ؟',
#   'label': 'Gulf'},
#  {'text': 'شلون امليه؟', 'translation': 'كيف أملئ هذه ؟', 'label': 'Gulf'},
#  {'text': 'تشوف مبنى ابيض على الشارع؟ هذي هو.',
#   'translation': 'ترى مبنى أبيض في الجانب الآخر من الشارع ، إنه هو .',
#   'label': 'Gulf'},
#  {'text': 'اكيد. خلني اشوف. شكلك انجرحت بالمرجان.',
#   'translation': 'بالتأكيد . دعني أراها . أظن أن المرجان جرحك .',
#   'label': 'Gulf'},
#  {'text': 'احتياط، عطني رقم الشخص المسؤول.',
#   'translation': 'لقط للتأكيد ، إعطني رقم المسئول .',
#   'label': 'Gulf'},
#  {'text': 'في طريق سريع؟',
#   'translation': 'هل هناك طريق حر ؟',
#   'label': 'Gulf'},
#  {'text': 'ادرس عشان اصير عالم.',
#   'translation': 'أنا ادرس لكي أصبح عالم .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تعطيني تذكرتين للكراسي المحجوزة؟',
#   'translation': 'هل من الممكن أن تعطني تذكرتين للمقاعد المحجوزة ؟',
#   'label': 'Gulf'},
#  {'text': 'لو سمحت افصخ ثيابك والبس هذي الروب.',
#   'translation': 'من فضلك اخلع ملابسك وارتدي هذا الثوب .',
#   'label': 'Gulf'},
#  {'text': 'ممكن تحط سرير زيادة في الغرفة؟',
#   'translation': 'هل من الممكن أن تضع سريرا إضافيا في الغرفة ؟',
#   'label': 'Gulf'},
#  {'text': 'ممكن عامل مكالمات ياباني؟',
#   'translation': 'هل يمكنني الحصول على عامل تليفون ياباني ؟',
#   'label': 'Gulf'},
#  {'text': 'خذ هذي لين توصل المحطة. من هناك عاد لازم تروح الفندق بروحك.',
#   'translation': 'خذ هذا حتى المحطة . من هناك عليك أن تذهب إلى الفندق على قدميك .',
#   'label': 'Gulf'},
#  {'text': 'ليش ما جا الحفلة امس؟',
#   'translation': 'لماذا لم يأت إلى الحفلة أمس ؟',
#   'label': 'Gulf'},
#  {'text': 'بغيت أأجر طراد ومرشد، لو سمحت.',
#   'translation': 'أريد أن أستأجر قارب بمرشد من فضلك .',
#   'label': 'Gulf'},
#  {'text': 'في حمام عام يمنا؟',
#   'translation': 'أتوجد حجرة استراحة عامة في مكان قريب من هنا ؟',
#   'label': 'Gulf'},
#  {'text': 'ورني اياه، لو سمحت.',
#   'translation': 'أرني إياها , من فضلك .',
#   'label': 'Gulf'},
#  ...]

# %%
with open("./dataset.json", "w", encoding="utf-8") as json_file:
    json.dump(data_entries, json_file, ensure_ascii=False, indent=4)

print("Data saved to dataset.json")
# Out:
# Data saved to dataset.json

# %%
import zipfile
import os
import json

# Define paths and files for each dialect
data_files = {
    "Gulf": ("Gulf_Dialects.txt", "MSA_For_Gulf_Dialects.txt"),
    "Iraqi": ("Iraqi_Dialects.txt", "MSA_For_Iraqi_Dialects.txt"),
    "Levantine": ("Levantine_Dialects.txt", "MSA_For_Levantine_Dialects.txt"),
    "Egyptian": ("Nile Basin_ Dialects.txt", "MSA_For_Nile_Basin_Dialects.txt"),
    "Maghrebian": ("North_Africa _Dialect.txt", "MSA_For_North_Africa_Dialects.txt")
}

# Unzip dataset
with zipfile.ZipFile("dialects_datasets.zip", "r") as zip_ref:
    zip_ref.extractall("dialects_data")

# Initialize list to hold each data entry as a dictionary
data_entries = []

# Function to read lines from a file
def read_lines(filepath):
    with open(filepath, "r", encoding="utf-8") as file:
        return file.readlines()

# Process each dialect's files
for dialect, (dialect_file, msa_file) in data_files.items():
    dialect_path = os.path.join("dialects_data", dialect_file)
    msa_path = os.path.join("dialects_data", msa_file)
    
    # Read lines from each file
    dialect_sentences = read_lines(dialect_path)
    msa_sentences = read_lines(msa_path)
    
    # Ensure same number of sentences in dialect and MSA files
    assert len(dialect_sentences) == len(msa_sentences), \
        f"Mismatch in lines for {dialect_file} and {msa_file}"
    
    # Combine text, translation, and label into a dictionary for each sentence pair
    for dialect_sentence, msa_sentence in zip(dialect_sentences, msa_sentences):
        data_entries.append({
            "text": dialect_sentence.strip(),
            "translation": msa_sentence.strip(),
            "label": dialect
        })

# Save as JSON file
with open("dataset.json", "w", encoding="utf-8") as json_file:
    json.dump(data_entries, json_file, ensure_ascii=False, indent=4)

print("Data saved to dataset.json")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 15
#       6 data_files = {
#       7     "Gulf": ("Gulf_Dialects.txt", "MSA_For_Gulf_Dialects.txt"),
#       8     "Iraqi": ("Iraqi_Dialects.txt", "MSA_For_Iraqi_Dialects.txt"),
#    (...)
#      11     "Maghrebian": ("North_Africa _Dialect.txt", "MSA_For_North_Africa_Dialects.txt")
#      12 }
#      14 # Unzip dataset
# ---> 15 with zipfile.ZipFile("dialects_datasets.zip", "r") as zip_ref:
#      16     zip_ref.extractall("dialects_data")
#      18 # Initialize list to hold each data entry as a dictionary
#
# File /opt/conda/envs/Python-RT24.1/lib/python3.11/zipfile.py:1294, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1292 while True:
#    1293     try:
# -> 1294         self.fp = io.open(file, filemode)
#    1295     except OSError:
#    1296         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: 'dialects_datasets.zip'

# %%
# !ls './'
# Out:
# dataset.json
